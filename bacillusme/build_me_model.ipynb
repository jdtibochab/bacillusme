# %% [markdown]
# # Build *Bacillus subtilis*

# %%
import scipy
scipy.__version__
# Out:
# '0.19.0'

# %%
from __future__ import print_function, division, absolute_import

import sys
sys.path.append('/home/jt/UCSD/bacillusme-master')

# python imports
import re
from os.path import join,dirname,abspath
from collections import defaultdict
import pickle

# third party imports
import pandas
import cobra

# COBRAme
import cobrame
from cobrame.util import building, mu, me_model_interface
from cobrame.io.json import save_json_me_model, save_reduced_json_me_model

# ECOLIme
import bacillusme
from bacillusme import (transcription, translation, flat_files, generics, formulas, compartments)
from bacillusme.util.helper_functions import *

# %load_ext autoreload
# %autoreload 2
print(cobrame.__file__)
print(bacillusme.__file__)
# Out:
# /home/jt/me_modeling/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/io/sbml3.py:24: UserWarning: Install lxml for faster SBML I/O
#   warn("Install lxml for faster SBML I/O")
# /home/jt/me_modeling/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/io/__init__.py:12: UserWarning: cobra.io.sbml requires libsbml
#   warn("cobra.io.sbml requires libsbml")
# /home/jt/me_modeling/lib/python3.6/site-packages/cobrame-0.0.9-py3.6.egg/cobrame/__init__.py
# /home/jt/me_modeling/lib/python3.6/site-packages/BACILLUSme-0.0.9-py3.6.egg/bacillusme/__init__.py

# %%
# Define Models
eco_directory = join(flat_files.ecoli_files_dir, 'iJO1366.json')
ijo_directory = join(flat_files.ecoli_files_dir, 'iYO844_mod.json')
uni_directory = join(flat_files.ecoli_files_dir, 'universal_model.json')

eco = cobra.io.load_json_model(eco_directory)
ijo = cobra.io.load_json_model(ijo_directory)
uni = cobra.io.load_json_model(uni_directory)

# %%
## M-model Fixes
ijo.reactions.BIOMASS_BS_10.lower_bound = 0
ijo.reactions.BIOMASS_BS_10.upper_bound = 0

# %% [markdown]
# ## Part 1: Create minimum solveable ME-model
# This will include the bare minimum representations of
# - Transcription Reactions
# - Translation Reactions
# - Complex Formation Reactions
# - Metabolic Reactions
#
# that still produce a working ME-model
#
# ### 1) Create Model Object and populate its global info
# This includes important parameters that are used to calculate coupling
# constraints as well as organism-specific information such as peptide
# processing types

# %%
me = cobrame.MEModel('iJT964-ME')

# ME-models require special OptLang interface if cobrapy version >= 0.6.0
# If cannot import SymbolicParameter, assume using cobrapy
# versions <= 0.5.11
try:
    from optlang.interface import SymbolicParameter
except:
    pass
else:
    me.solver = me_model_interface

# "Translational capacity" of organism
me.global_info['kt'] = 4.5  # (in h-1)scott 2010, RNA-to-protein curve fit
me.global_info['r0'] = 0.087  # scott 2010, RNA-to-protein curve fit
me.global_info['k_deg'] = 1.0/5. * 60.0  # 1/5 1/min 60 min/h # h-1

# Molecular mass of RNA component of ribosome
me.global_info['m_rr'] = 1453. # in kDa

# Average molecular mass of an amino acid
me.global_info['m_aa'] = 109. / 1000.  # in kDa

# Proportion of RNA that is rRNA
me.global_info['f_rRNA'] = .86
me.global_info['m_nt'] = 324. / 1000.  # in kDa
me.global_info['f_mRNA'] = .02

# tRNA associated global information
me.global_info['m_tRNA'] = 25000. / 1000.  # in kDA
me.global_info['f_tRNA'] = .12

# Folding Properties
me.global_info['temperature'] = 37
me.global_info['propensity_scaling'] = .45

# DNA Replication Parameters
me.global_info['GC_fraction'] = 0.507896997096

# Define the types of biomass that will be synthesized in the model
me.add_biomass_constraints_to_model(["protein_biomass", "mRNA_biomass", "tRNA_biomass", "rRNA_biomass",
                                     "ncRNA_biomass", "DNA_biomass", "lipid_biomass", "constituent_biomass",
                                     "prosthetic_group_biomass", "peptidoglycan_biomass"])

# Define ME-model compartments
me.compartments = {"p": "Periplasm", "e": "Extra-organism", "c": "Cytosol", 
                   "im": 'Inner Membrane', 'om': "Outer Membrane", "mc": "ME-model Constraint",
                   "m": "Membrane"}

# %% [markdown]
# ### 2) Load metabolites and build Metabolic reactions
# The below reads in:
# - Required
#  * **reaction_matrix.txt** (reaction matrix w/ reactions unlumped, metabolites renamed etc.)
#  * **metabolites.txt** (metabolite properties)
#  * **reactions.txt** (info on reversiblity, whether enzyme catalyzed etc.)
#  * **m_to_me_mets.csv** (mapping of enzymes/complexes used in M-model to their ME-model compatible ID)
#  * **protein_complexes.txt** (protein subunit stoichiometry of all complexes, used to identify metabolites as such)
#
# It creates a new e coli M-model from this info then incorporates it into the ME-model using *add_m_model_content*. metabolites are added directly reactions are added as StoichiometricData
#
# Metabolite types have different properties in an ME-model so enzyme complexes need added to the model as Complexes not Metabolites. Components in the E. coli M-model that are actually Complexes are compiled in *complex_list*

# %%
# m_model = flat_files.get_m_model()
m_model = flat_files.process_m_model(ijo, 'metabolites.txt',
                                     'm_to_me_mets.csv', 'reactions.txt',
                                     'reaction_matrix.txt',
                                     'protein_complexes.txt',
                                     defer_to_rxn_matrix=set())
m_model.reactions.EX_glc__D_e.id = 'EX_glc__D_e'
m_model.repair()
# some of the "metabolites" in iJO1366 "M" model are actually complexes. We pass those in
# so they get created as complexes, not metabolites.
complexes = flat_files.get_complex_subunit_stoichiometry(
    'protein_complexes.txt').keys()
complex_set = set(
    [i.id for i in m_model.metabolites if i.id.split('_mod_')[0] in complexes])
building.add_m_model_content(me, m_model, complex_metabolite_ids=complex_set)
# Out:
# /home/jt/UCSD/bacillusme-master/bacillusme/flat_files.py:60 UserWarning: Complex (BSU34550-MONOMER) in complex_stoichiometry_file twice
# BSU15920-MONOMER_mod_pan4p
# BSU15920-MONOMER
# BSU28500-MONOMER_mod_Oxidized
# BSU28500-MONOMER
# /home/jt/UCSD/bacillusme-master/bacillusme/corrections.py:28 UserWarning: Creating new metabolite (4fe4s_c)
# /home/jt/UCSD/bacillusme-master/bacillusme/corrections.py:28 UserWarning: Creating new metabolite (2fe2s_c)

# %%
# This adds exchange reactions for metabolites not contained in iJO1366
# Some of these cannot be produced by the model so they are added here
exchange_list = ['4fe4s_c','2fe2s_c','udcpp_c','pydx5p_c','3fe4s_c','cl_c','sheme_c','cu_c','mn2_c',
                 'bmocogdp_c','dpm_c','thmpp_c','zn2_c','cbl1_c','cobalt2_c']
transport_candidates = {}
bsub_ecoli_blast = pd.read_csv('./building_data/blast_out_bsub_as_ref.txt',sep='\t',index_col=2)
for met_id in exchange_list:   
    # Identify or create metabolites
    if hasattr(me.metabolites,met_id):
        met = me.metabolites.get_by_id(met_id)
    else:
        met = cobrame.Metabolite(met_id)
    met_e_id = re.sub('_.','_e',met_id)
    if hasattr(me.metabolites,met_e_id):
        met_e = me.metabolites.get_by_id(met_e_id)
    else:
        met_e = cobrame.Metabolite(met_e_id)
        
    # Identify or create exchange reaction
    ex_id = 'EX_{}'.format(met_e_id)
    if hasattr(me.reactions,ex_id):
        ex_r = me.reactions.get_by_id(ex_id)
    else:
        ex_r = cobrame.MEReaction(ex_id)
        ex_r.add_metabolites({met_e:-1})
        me.add_reaction(ex_r)
    ex_r.upper_bound = 0 # Avoid secretion of this metabolites. These reactions are
                         # only meant to supply cofactors for which no biosynthetic 
                         # pathway has been defined in the model.
    ex_r.lower_bound = -1000
    
    # Identify or create transport reaction. Available transport reactions in model?
    met_prod_rxns = [rxn.id for rxn in get_reactions_of_met(m_model,met.id,s=1,verbose=0)]
    met_e_cons_rxns = [rxn.id for rxn in get_reactions_of_met(m_model,met_e.id,s=-1,verbose=0)]
    transport = list(set(met_prod_rxns)&set(met_e_cons_rxns))
    ref = 'none'
    if transport:
        ref = 'bsub'
        for r in transport:
            rxn = m_model.reactions.get_by_id(r)
            rxn.lower_bound = 0
            rxn.upper_bound = 1000
            print('Found in model:',met_id,r,rxn.reaction)
    else:
        # In E. coli as template?
        transporters = []
        met_prod_rxns = [rxn.id for rxn in get_reactions_of_met(eco,re.sub('_.','_p',met.id),s=1,verbose=0)]
        met_e_cons_rxns = [rxn.id for rxn in get_reactions_of_met(eco,met_e.id,s=-1,verbose=0)]
        transport = list(set(met_prod_rxns)&set(met_e_cons_rxns))
        if transport:
            ref = 'eco'
            for r in transport:
                rxn = eco.reactions.get_by_id(r)
                transporters = [bsub_ecoli_blast.loc[gene.id]['BSUB_gene'] for gene in rxn.genes \
                                    if gene.id in bsub_ecoli_blast.index]
                if transporters:
                    transport_candidates[met_id] = transporters
                    print('Manually curate: ', met_id, transport)
                else:
                    art = 1
        else:
            art = 1
        if art:
            ## Add artificial reaction
            t_r = cobrame.MEReaction(met_id.split('_')[0].upper()+'t')
            t_r.add_metabolites({met_e:-1,met:1})
            print('Artificially added: ', met_id)
            me.add_reaction(t_r)
    #_ = get_reactions_of_met(me,met_e.id)
# Out:
# Artificially added:  4fe4s_c
# Artificially added:  2fe2s_c
# Artificially added:  udcpp_c
# Artificially added:  pydx5p_c
# Artificially added:  3fe4s_c
# Manually curate:  cl_c ['CLtex']
# Artificially added:  cl_c
# Artificially added:  sheme_c
# Found in model: cu_c Cut1 atp_c + cu_e + h2o_c --> adp_c + cu_c + h_c + pi_c
# Found in model: mn2_c CITt11 cit_e + h_e + mn2_e --> cit_c + h_c + mn2_c
# Found in model: mn2_c MNabc atp_c + h2o_c + mn2_e --> adp_c + h_c + mn2_c + pi_c
# Found in model: mn2_c MNt2 h_e + mn2_e --> h_c + mn2_c
# Artificially added:  bmocogdp_c
# Artificially added:  dpm_c
# Artificially added:  thmpp_c
# Found in model: zn2_c ZNabc atp_c + h2o_c + zn2_e --> adp_c + h_c + pi_c + zn2_c
# Found in model: zn2_c CITt15 cit_e + h_e + zn2_e --> cit_c + h_c + zn2_c
# Found in model: cbl1_c CBLtex cbl1_e --> cbl1_c
# Found in model: cobalt2_c CITt13 cit_e + cobalt2_e + h_e --> cit_c + cobalt2_c + h_c
# Found in model: cobalt2_c COBALTt5 cobalt2_e --> cobalt2_c

# %% [markdown]
# ### 3) Add Transcription and Translation
# The below reads in:
# - Required
#  * **NC_000913.2.gb** (Genbank sequence annotation)
#  * **ecolime/translation.py** (codon to tRNA mapping)
# - Optional
#  * **TUs_from_ecocyc.txt** (TU definitions, start/stop positions, etc.)
#  * **ecolime/translation.py** (dictionary of gene to frameshift mutation)
#
# To construct the bare minimimum components of a transcription and translation reactions. For example, transcription reactions at this point include nucleotides and the synthesized RNAs.

# %%
element_types = {'CDS', 'rRNA','tRNA', 'ncRNA','misc_RNA'}

# %%
gb_filename = join(flat_files.ecoli_files_dir,'NC_000964.gb')                                                                                    
tu_df = flat_files.get_tu_dataframe('TUs_from_bsubcyc.txt')

building.build_reactions_from_genbank(me, gb_filename, tu_df, verbose=False,
                                      frameshift_dict=translation.frameshift_dict,
                                      trna_to_codon=translation.trna_to_codon,
                                      element_types = element_types)
# Out:
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_1 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_2 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_3 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_4 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_5 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_6 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_64 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_7 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_65 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_66 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_8 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_9 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_10 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_11 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_12 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_13 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_67 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_14 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_15 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_16 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_17 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_18 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_19 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_68 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_87 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_20 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_21 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_22 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_88 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_69 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_70 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_23 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_24 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_25 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_26 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_27 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_28 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_29 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_30 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_71 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_89 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_72 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_73 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_31 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_74 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_75 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_32 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_76 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_33 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_90 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_77 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_34 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_35 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_78 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_36 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_91 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_37 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_39 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_79 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_80 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_81 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_92 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_82 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_40 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_41 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_42 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_43 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_44 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_45 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_46 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_47 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_48 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_93 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_83 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_49 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_50 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_51 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_52 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_84 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_53 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_85 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_54 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_55 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_56 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_57 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_58 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_59 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_60 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_61 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_62 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_63 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_86 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:320 UserWarning: Processing BSU_misc_RNA_94 as ncRNA
# /home/jt/UCSD/cobrame-master/cobrame/core/reaction.py:854 UserWarning: RNA Polymerase  not found
# /home/jt/UCSD/cobrame-master/cobrame/core/reaction.py:1096 UserWarning: ribosome not found
# /home/jt/UCSD/cobrame-master/cobrame/core/reaction.py:1139 UserWarning: RNA_degradosome not found

# %% [markdown]
# ### 4) Add in complex Formation without modifications (for now)
#
# The below reads in:
# - Required
#  * **protein_complexes.txt** (Metabolic complexes' protein subunit stoichiometries)
#  * **protein_modification.txt** (Type and number of modifications for each protein)

# %%
# complex_stoichiometry_dict is a dict of {'complex_id': [{'bnum' : count}]}
rna_components = {'BSU_misc_RNA_2','BSU_misc_RNA_35'} # component id should have 'RNA_ instead' of 'protein_'
# get Metabolic Complex composition from ECOLIme
complex_stoichiometry_dict = flat_files.get_complex_subunit_stoichiometry('protein_complexes.txt', rna_components)
# add complexes to model
complex_modification_dict = flat_files.get_complex_modifications('protein_modification.txt', 'protein_complexes.txt')
building.add_model_complexes(me, complex_stoichiometry_dict, complex_modification_dict, verbose=False)

# remove modifications. they will be added back in later
for data in me.complex_data:
    data.subreactions = {}
# add formation reactions for each of the ComplexDatas
for cplx_data in me.complex_data:
    formation = cplx_data.formation
    if formation:
        formation.update()
    else:
        cplx_data.create_complex_formation()
# Out:
# /home/jt/UCSD/bacillusme-master/bacillusme/flat_files.py:60 UserWarning: Complex (BSU34550-MONOMER) in complex_stoichiometry_file twice
# Created <TranslatedGene protein_BSU29679 at 0x7f7a252a99e8> in <ComplexFormation formation_BSU29679-MONOMER at 0x7f7a252a9908>
# Created <TranslatedGene protein_G8J2-7 at 0x7f7a24339438> in <ComplexFormation formation_MONOMER8J2-7 at 0x7f7a243395c0>
# Created <TranslatedGene protein_G8J2-20 at 0x7f7a26af80f0> in <ComplexFormation formation_MONOMER8J2-49 at 0x7f7a26af84e0>
# Created <TranslatedGene protein_G8J2-176 at 0x7f7a24eb6710> in <ComplexFormation formation_MONOMER8J2-60 at 0x7f7a24eb6588>
# Created <TranslatedGene protein_G8J2-19 at 0x7f7a2274e0b8> in <ComplexFormation formation_MONOMER8J2-48 at 0x7f7a22748e80>
# Created <TranslatedGene protein_G8J2-18 at 0x7f7a2274e208> in <ComplexFormation formation_MONOMER8J2-47 at 0x7f7a2274e278>
# Created <TranslatedGene protein_G8J2-16 at 0x7f7a2274e080> in <ComplexFormation formation_MONOMER8J2-46 at 0x7f7a2274e1d0>
# Created <TranslatedGene protein_G8J2-13 at 0x7f7a2274e550> in <ComplexFormation formation_MONOMER8J2-45 at 0x7f7a2274e390>
# Created <TranslatedGene protein_G8J2-173 at 0x7f7a223a7400> in <ComplexFormation formation_MONOMER8J2-58 at 0x7f7a223a73c8>
# Created <TranslatedGene protein_G8J2-175 at 0x7f7a223a74a8> in <ComplexFormation formation_MONOMER8J2-59 at 0x7f7a223a7940>
# Created <TranslatedGene protein_G8J2-21 at 0x7f7a223a7828> in <ComplexFormation formation_MONOMER8J2-50 at 0x7f7a223a7e10>
# Created <TranslatedGene protein_G8J2-162 at 0x7f7a223a7cf8> in <ComplexFormation formation_MONOMER8J2-52 at 0x7f7a223a7d30>
# Created <TranslatedGene protein_G8J2-163 at 0x7f7a223ad278> in <ComplexFormation formation_MONOMER8J2-55 at 0x7f7a223ad080>
# Created <TranslatedGene protein_G8J2-170 at 0x7f7a223ad1d0> in <ComplexFormation formation_MONOMER8J2-56 at 0x7f7a223ad438>
# Created <TranslatedGene protein_G8J2-171 at 0x7f7a223ad5c0> in <ComplexFormation formation_MONOMER8J2-57 at 0x7f7a223ad160>
# Created <TranslatedGene protein_BSU23060 at 0x7f7a223b5d30> in <ComplexFormation formation_BSU23060-MONOMER at 0x7f7a223b5b70>
# Created <TranslatedGene protein_BSU07540 at 0x7f7a22366d30> in <ComplexFormation formation_BSU07540-MONOMER at 0x7f7a22366cc0>

# %% [markdown]
# ### 5) Add dummy reaction to model and unmodeled_protein_fraction
#
# Includes the transcription, translation, complex_formation, and metabolic reaction. Sequence based on prevelance of each codon found in *E. coli*.
#  - Required
#      * [**codon_usage.csv**](http://openwetware.org/wiki/Escherichia_coli/Codon_usage) (codon prevelance)

# %%
seq = "ATG"
codons = pandas.read_csv(join(flat_files.ecoli_files_dir, "codon_usage.csv"), index_col=1)
for codon, row in codons.iterrows():
    if row.amino_acid == "Stop":
        continue
    seq += codon * int(row.per_1000 // 3)  # want roughly 300 aa
# get the most used stop codon
seq += codons[codons.amino_acid == "Stop"].sort_values("per_1000").index[-1]
building.add_dummy_reactions(me, seq, update=True)

# dummy proteins can be used to catalyze orphan reactions. This
# ensures that orphan reactions will not becore favored to fulfil 
# unmodeled protein fraction requirement 
rxn = cobrame.SummaryVariable('dummy_protein_to_mass')
me.add_reactions([rxn])
mass = me.metabolites.protein_dummy.formula_weight / 1000.  # in kDa
rxn.add_metabolites({'protein_biomass': -mass, 'protein_dummy': -1,
                     cobrame.Constraint('unmodeled_protein_biomass'): mass})

# %%
get_reactions_of_met(me,'unmodeled_protein_biomass')
# Out:
# ( dummy_protein_to_mass 0.0 1000.0 ) 	 34.13274694 protein_biomass + protein_dummy --> 34.13274694 unmodeled_protein_biomass
# [<SummaryVariable dummy_protein_to_mass at 0x7f7a222509b0>]

# %%
for r in me.reactions:
    if 'biomass' in r.id:
        print(r.id, r.reaction , r.bounds)
# Out:
# biomass_dilution biomass -->  (mu, mu)
# protein_biomass_to_biomass protein_biomass --> biomass (0.0, 1000.0)
# mRNA_biomass_to_biomass mRNA_biomass --> biomass (0.0, 1000.0)
# tRNA_biomass_to_biomass tRNA_biomass --> biomass (0.0, 1000.0)
# rRNA_biomass_to_biomass rRNA_biomass --> biomass (0.0, 1000.0)
# ncRNA_biomass_to_biomass ncRNA_biomass --> biomass (0.0, 1000.0)
# DNA_biomass_to_biomass DNA_biomass --> biomass (0.0, 1000.0)
# lipid_biomass_to_biomass lipid_biomass --> biomass (0.0, 1000.0)
# constituent_biomass_to_biomass constituent_biomass --> biomass (0.0, 1000.0)
# prosthetic_group_biomass_to_biomass prosthetic_group_biomass --> biomass (0.0, 1000.0)
# peptidoglycan_biomass_to_biomass peptidoglycan_biomass --> biomass (0.0, 1000.0)

# %%
for r in me.metabolites.unmodeled_protein_biomass.reactions:
    print(r.id,r.reaction)
# Out:
# dummy_protein_to_mass 34.13274694 protein_biomass + protein_dummy --> 34.13274694 unmodeled_protein_biomass

# %%
for r in me.metabolites.protein_dummy.reactions:
    print(r.id,r.reaction)
# Out:
# formation_CPLX_dummy protein_dummy --> CPLX_dummy
# translation_dummy 0.000498399634202103*mu + 0.000195123456790123 + 0.00598079561042524*(mu + 0.3915)/mu RNA_dummy + 24 ala__L_c + 11 arg__L_c + 12 asn__L_c + 17 asp__L_c + 1.37109739368999*(mu + 0.3915)/mu atp_c + 2 cys__L_c + 12 gln__L_c + 23 glu__L_c + 21 gly_c + 7 his__L_c + 24 ile__L_c + 29 leu__L_c + 22 lys__L_c + 1.74892209872384*(mu + 0.3915)/mu mRNA_biomass + 9 met__L_c + 13 phe__L_c + 11 pro__L_c + 18 ser__L_c + 16 thr__L_c + 3 trp__L_c + 11 tyr__L_c + 20 val__L_c --> 1.37109739368999*(mu + 0.3915)/mu adp_c + 1.41146776406036*(mu + 0.3915)/mu amp_c + 1.30979423868313*(mu + 0.3915)/mu cmp_c + 1.08252400548697*(mu + 0.3915)/mu gmp_c + 304.0 - 1.37109739368999*(mu + 0.3915)/mu h2o_c + 1.37109739368999*(mu + 0.3915)/mu h_c + 1.37109739368999*(mu + 0.3915)/mu pi_c + 34.13274694 protein_biomass + protein_dummy + 1.68658436213992*(mu + 0.3915)/mu ump_c
# dummy_protein_to_mass 34.13274694 protein_biomass + protein_dummy --> 34.13274694 unmodeled_protein_biomass

# %% [markdown]
# ### 6) Assocated Complexes and build Metabolic Reactions
# - Required
#     * **enzyme_reaction_association.txt**
#     * **reactions.txt** (gives reaction name, reversiblity, source and whether reaction is spontaneous)

# %%
# associate reaction id with the old ME complex id (including modifications)
rxn_to_cplx_dict = flat_files.get_reaction_to_complex(m_model)
rxn_info = flat_files.get_reaction_info_frame('reactions.txt')

# Required to add dummy reaction as spontaneous reaction
rxn_info = rxn_info.append(pandas.Series({'description': 'dummy reaction', 'is_reversible': 0,
                                          'is_spontaneous':1}, name='dummy_reaction'))

building.add_reactions_from_stoichiometric_data(me, rxn_to_cplx_dict, rxn_info, update=True)
# Out:
# /home/jt/UCSD/cobrame-master/cobrame/util/building.py:728 UserWarning: Reaction (BIOMASS_BS_10) cannot carry flux

# %% [markdown]
# ### 7) Incorporate remaining biomass constituents
# There are leftover components from the *i*JO1366 biomass equation that either:
# 1. have no mechanistic function in the model (glycogen)
# 2. are cofactors that are regenerated (nad)
#
# Applies demands and coefficients from the *i*JO1366 biomass objective function

# %%
me.ngam = 9.
me.gam = 105.053483
me.unmodeled_protein_fraction = .36

biomass_constituents = {
    "10fthf_c": -0.000367,
    "peptido_BS_c": -.101817,
    "psetha_BS_c": -0.00056,
    "mql7_c":-0.000266,
}


rxn = cobrame.SummaryVariable('biomass_constituent_demand')
me.add_reactions([rxn])
rxn.add_metabolites(biomass_constituents)
constituent_mass = sum(me.metabolites.get_by_id(c).formula_weight / 1000. * -v
                     for c, v in biomass_constituents.items())
rxn.lower_bound = mu
rxn.upper_bound = mu
rxn.add_metabolites({me.metabolites.constituent_biomass: constituent_mass})
# Out:
# /home/jt/UCSD/cobrame-master/cobrame/core/model.py:103 UserWarning: Adding ATPM reaction to model
# /home/jt/UCSD/cobrame-master/cobrame/core/model.py:86 UserWarning: Adding GAM reaction to model

# %% [markdown]
#  #### Lipid components
#  Metabolites and coefficients from *i*JO1366 biomass objective function

# %%
# Identify lipid metabolites in biomass equation

lipid_demand = {}
for key, value in ijo.reactions.BIOMASS_BS_10.metabolites.items():
    if '_BS_c' in key.id and not key.id in biomass_constituents:
        lipid_demand[key.id] = abs(value)
                
for met, requirement in lipid_demand.items():
    component_mass = me.metabolites.get_by_id(met).formula_weight / 1000.
    rxn = cobrame.SummaryVariable('Demand_' + met)
    me.add_reactions([rxn])
    rxn.add_metabolites({met: -1 * requirement,
                         'lipid_biomass': component_mass * requirement})
    rxn.lower_bound = mu
    rxn.upper_bound = 1000.

# Kdo2lipid4
#requirement = 0.01945  # in mmol/gDW
#met = me.metabolites.get_by_id('kdo2lipid4_e')
#component_mass = met.formula_weight / 1000.
#rxn = cobrame.SummaryVariable('Demand_' + met.id)
#me.add_reactions([rxn])

#rxn.add_metabolites({met.id : -1.*requirement,
#                     'lipid_biomass': component_mass * requirement})
#rxn.lower_bound = mu
#rxn.upper_bound = mu

# %% [markdown]
# #### DNA Demand Requirements
# Added based on growth rate dependent DNA levels as in [O'brien EJ et al 2013](https://www.ncbi.nlm.nih.gov/pubmed/24084808)

# %%
dna_demand_stoich, dna_demand_bound = bacillusme.dna_replication.return_gr_dependent_dna_demand(
    me, me.global_info['GC_fraction'])

dna_replication = cobrame.SummaryVariable("DNA_replication")
me.add_reaction(dna_replication)
dna_replication.add_metabolites(dna_demand_stoich)
dna_biomass = cobrame.Constraint("DNA_biomass")

dna_mw = 0
dna_mw_no_ppi = bacillusme.dna_replication.get_dna_mw_no_ppi_dict(me)
for met, value in me.reactions.DNA_replication.metabolites.items():
    if met.id != 'ppi_c':
        dna_mw -= value * dna_mw_no_ppi[met.id.replace('_c','')] / 1000.
        
dna_replication.add_metabolites({dna_biomass: dna_mw})
dna_replication.lower_bound = dna_demand_bound 
dna_replication.upper_bound = dna_demand_bound

# %% [markdown]
# **Note**: From this point forward, executing every codeblock should result in a solveable ME-model
#
# ------
#
# ## Part 2: Add metastructures to solving ME-model
# This includes:
# 1. ribosome
# 2. RNA polymerase
# 3. charged_tRNAs

# %% [markdown]
# Sometimes multiple entities can perform the same role. To prevent a combinatorial explosion of possibilities, we can create  "generic" version, where any of those entities can fill in.

# %%
for generic, components in generics.generic_dict.items():
    cobrame.GenericData(generic, me, components).create_reactions()

# %% [markdown]
# ### 1) Add ribosome
# This uses the ribosome composition definition in **ecolime/ribosome.py**

# %%
bacillusme.ribosome.add_ribosome(me, verbose=False)
# Out:
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (mg2_c) does not have formula

# %% [markdown]
# ### 2) Add charged tRNA reactions

# %% [markdown]
# The tRNA charging reactions were automatically added when loading the genome from the genbank file. However, the charging reactions still need to be made aware of the tRNA synthetases which are responsible.
#
# Uses **trna_charging.py**

# %%
aa_synthetase_dict = bacillusme.trna_charging.amino_acid_trna_synthetase
for data in me.tRNA_data:
    data.synthetase = str(aa_synthetase_dict[data.amino_acid])

# %% [markdown]
# Generic charged tRNAs are added to translation reactions via SubreactionData below.
#
# All new data added in this block contained in **ecolime/translation.py**

# %%
bacillusme.translation.add_charged_trna_subreactions(me)
for data in me.translation_data:
    data.add_initiation_subreactions(start_codons=translation.translation_start_codons,
                                    start_subreactions=set(translation.initiation_subreactions.keys()))

    data.add_elongation_subreactions(elongation_subreactions=set(translation.elongation_subreactions.keys()))

    data.add_termination_subreactions(translation_terminator_dict=translation.translation_stop_dict)
# Out:
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:870 UserWarning: initiation subreaction Translation_initiation_factor_InfA not in model
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:870 UserWarning: initiation subreaction Translation_initiation_factor_InfC not in model
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:870 UserWarning: initiation subreaction Translation_gtp_initiation_factor_InfB not in model
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:870 UserWarning: initiation subreaction fmet_addition_at_START not in model
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:836 UserWarning: elongation subreaction Tuf_gtp_regeneration not in model
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:836 UserWarning: elongation subreaction FusA_mono_elongation not in model
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU05343 starts with 'UGC' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU05343
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU05344 starts with 'GCU' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU05890 starts with 'UUU' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU05899
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU06033 starts with 'GAG' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU06033
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU06074
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU06076 starts with 'UUA' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU06076
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU06078 starts with 'UUU' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU06079 starts with 'GAC' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU06079
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU06083
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU07170
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU11381
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU11382 starts with 'GGC' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU12680 starts with 'AUC' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU16890
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU16900 starts with 'AGG' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU17266
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU19810
# Adding selenocystein for BSU20040
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:801 UserWarning: tRNA addition subreaction sec_addition_at_UGA not in model
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU20040
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU20060 starts with 'CAA' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU20060
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU21599 starts with 'AAU' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU21670 starts with 'UCU' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU23330
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU23836 starts with 'UGC' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU23836
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU26039 starts with 'AGC' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU26040
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU26748 starts with 'AUA' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU26749
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU26750
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU32960 starts with 'GGC' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU32970
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU35290 starts with 'GAC' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU35290
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU35609 starts with 'UGG' which is not a start codon
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:900 UserWarning: No termination enzyme for RNA_BSU35610
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:863 UserWarning: RNA_BSU39029 starts with 'AAA' which is not a start codon

# %% [markdown]
# ### 3) Add Transcription Metacomplexes
# #### RNA Polymerase
#
# Data for RNA_polymerase composition fround in **ecolime/transcription**
#
# Uses *tu_df* from **TUs_from_ecocyc.txt**, above

# %%
for met in transcription.rna_polymerases:
    rnap_obj = cobrame.RNAP(met)
    me.add_metabolites(rnap_obj)
transcription.add_rna_polymerase_complexes(me, verbose=False)

# associate the correct RNA_polymerase and factors to TUs
sigma_to_rnap_dict = transcription.sigma_factor_complex_to_rna_polymerase_dict
for tu_id in tu_df.index:
    transcription_data = me.process_data.get_by_id(tu_id)
    sigma = tu_df.sigma[tu_id]
    rna_polymerase = sigma_to_rnap_dict[sigma]
    transcription_data.RNA_polymerase = rna_polymerase

# %% [markdown]
# #### Degradosome (both for RNA degradation and RNA splicing)
#
# All new data contained in **transcription.py**

# %%
me.add_metabolites([cobrame.Complex('RNA_degradosome')])
data = cobrame.ComplexData('RNA_degradosome', me)
for subunit, value in transcription.rna_degradosome.items():
    data.stoichiometry[subunit] = value
data.create_complex_formation(verbose=False)

# Used for RNA splicing
data = cobrame.SubreactionData('RNA_degradation_machine', me)
data.enzyme = 'RNA_degradosome'

data = cobrame.SubreactionData('RNA_degradation_atp_requirement', me)
# .25 water equivaltent for atp hydrolysis per nucleotide
data.stoichiometry = {'atp_c': -.25, 'h2o_c': -.25, 'adp_c': .25,
                      'pi_c': .25, 'h_c': .25}

transcription.add_rna_splicing(me)

# %% [markdown]
# ------
# ## Part 3: Add remaining modifications
# rRNA modifications handled in *add_ribosome*
#
# ### 1) Add complex modifications
# *complex_modification_dict* from **protein_modification.text**, above
#
# The rest of the new data contained in **ecolime/modifications.py**

# %%
for complex_id, info in complex_modification_dict.items():
    modifications = {}
    for mod, value in info['modifications'].items():
        # stoichiometry of modification determined in 
        # subreaction_data.stoichiometry
        
        modifications['mod_' + mod] = abs(value)
    me.process_data.get_by_id(complex_id).subreactions = modifications

# Adds modification data for more complicated enzyme modifications
# (ie, iron sulfur cluster modification)
bacillusme.modifications.add_modification_procedures(me)

# %%
with open("./me_models/iBS_checkpoint.pickle", "wb") as outfile:
    pickle.dump(me, outfile)

# %%
with open("./me_models/iBS_checkpoint.pickle", "rb") as outfile:
    me = pickle.load(outfile)

# %%
# add formation reactions for each of the ComplexDatas
for cplx_data in me.complex_data:
    formation = cplx_data.formation
    if 'Oxidized' not in cplx_data.id: 
        if formation:
            formation.update()
        else:
            cplx_data.create_complex_formation()
# Out:
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (cu_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (mn2_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (zn2_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (cbl1_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (ca2_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (cobalt2_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (ni2_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (fe2_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (pheme_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (dpm_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (cu2_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (cl_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (sheme_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (3fe4s_c) does not have formula
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (bmocogdp_c) does not have formula

# %% [markdown]
# ### 2) Add tRNA mods and asocciate them with tRNA charging reactions
# New data from:
# 1. **ecolime/trna_charging.py** (read via *add_tRNA_modification_procedures()*)
# 2. **post_transcriptional_modification_of_tRNA.txt** (modification types per tRNA)

# %%
# Add tRNA modifications to ME-model
bacillusme.trna_charging.add_trna_modification_procedures(me)

# trna_modifications = {tRNA_id: {modifications: count}}
trna_modifications=flat_files.get_trna_modification_targets()
for trna in trna_modifications:
    for data in me.process_data.query(trna):
        data.subreactions = trna_modifications[trna]

# %% [markdown]
# ---
# ## Part 4: Add remaining subreactions
# ### 1) Add translation related subreactions
# All new data from **ecolime/translation.py**

# %%
# add the translation subreaction data objects to model
translation.add_translation_subreactions_to_model(me)

# add translation subreaction data to reactions
methionine_cleaved=translation.methionine_cleaved
folding_dict=translation.folding_dict

for data in me.translation_data:
    locus_id = data.id
    if locus_id in methionine_cleaved:
        data.subreactions['N_terminal_methionine_cleavage'] = 1

    for folding_type in folding_dict:
        if locus_id in folding_dict[folding_type]:
            data.subreactions[folding_type] = 1

    # This block was ran above, but should be ran again to 
    # incorporate any subreactions not added previously
    data.add_initiation_subreactions(
        start_codons=translation.translation_start_codons,
        start_subreactions=set(translation.initiation_subreactions.keys()))
    data.add_elongation_subreactions(
        elongation_subreactions=set(translation.elongation_subreactions.keys()))
    data.add_termination_subreactions(
        translation_terminator_dict=translation.translation_stop_dict)

    # add organism specific subreactions associated with peptide processing
    for subrxn in translation.peptide_processing_subreactions:
        data.subreactions[subrxn] = 1
# Out:
# Adding selenocystein for BSU20040

# %% [markdown]
# ### 2) Add transcription related subreactions
# All new data from **ecolime/transcription.py**

# %%
for subreaction in transcription.transcription_subreactions:
    subreaction_data = cobrame.SubreactionData(subreaction, me)
    enzymes = transcription.transcription_subreactions[subreaction]['enzymes']
    subreaction_data.stoichiometry = transcription.transcription_subreactions[subreaction]['stoich']
    subreaction_data.enzyme = enzymes

for transcription_data in me.transcription_data:
    # Assume false if not in tu_df
    rho_dependent = tu_df.rho_dependent.get(transcription_data.id, False)
    rho = 'dependent' if rho_dependent else 'independent'
    stable = 'stable' if transcription_data.codes_stable_rna else 'normal'
    transcription_data.subreactions['Transcription_%s_rho_%s' % (stable,
                                                                 rho)] = 1

# %% [markdown]
# ----
# ## Part 5: Add in translocation
#
# New data from:
# 1. **peptide_compartment_and_pathways.txt** (Protein compartment and translocation pathway for each membrane complex)
# 2. **ecolime/translocation.py** (definitions of each translocation pathway)

# %%
# Add TranslocationData
transloc = pandas.read_csv(join(flat_files.ecoli_files_dir,"peptide_compartment_and_pathways.txt"),
                           sep='\t', comment="#")
for pathway, info in bacillusme.translocation.pathway.items():
    if 'alt' not in pathway:
        transloc_data = cobrame.TranslocationData(pathway + '_translocation', me)
    else:
        transloc_data = cobrame.TranslocationData(pathway.replace('_alt', '_translocation_alt'), me)
    transloc_data.enzyme_dict = info['enzymes']
    transloc_data.keff = info['keff']
    transloc_data.length_dependent_energy = info['length_dependent_energy']
    transloc_data.stoichiometry = info['stoichiometry']

# Associate data and add translocation reactions
bacillusme.translocation.add_translocation_pathways(me, transloc, membrane_constraints = False)

# Update stoichiometry of membrane complexes
# new_stoich = {complex_id: protein_w_compartment}
new_stoich = defaultdict(dict)
for cplx, row in transloc.set_index('Complex').iterrows():
    if cplx == 'EG10544-MONOMER':
        continue
    protein = row.Protein.split('(')[0] + '_' + row.Protein_compartment
    value = me.process_data.get_by_id(cplx).stoichiometry['protein_' + row.Protein.split('(')[0]]
    new_stoich[cplx]['protein_' + protein] = float(value)

for cplx, stoich in new_stoich.items():
    complex_data = me.process_data.get_by_id(cplx)
    for met, value in stoich.items():
        complex_data.stoichiometry.pop(met[0:16])
        complex_data.stoichiometry[met] = value
        complex_data.formation.update()
    # Complex ids in protein compartment file doesn't include mods
    # Some have multiple alternative modifications so must loop through these
    for complex_data in me.process_data.query(cplx + '_mod_'):
        for met, value in stoich.items():
            complex_data.stoichiometry.pop(met[0:16])
            complex_data.stoichiometry[met] = value
            complex_data.formation.update()

# %% [markdown]
# ---
# ## Part 6: Add Cell Wall Components
# All new data from **ecolime/translocation.py**

# %%
compartment_dict = {}
for prot, compartment in transloc.set_index('Protein').Protein_compartment.to_dict().items():
    compartment_dict[prot.split('(')[0]] = compartment

# %% [markdown]
# #### Add lipid modification SubreactionData

# %%
# Bsub m-model doest not have pe and pg metabolites

# %% [markdown]
# #### Braun's lipoprotein demand
# Metabolites and coefficients as defined in [Liu et al 2014](http://bmcsystbiol.biomedcentral.com/articles/10.1186/s12918-014-0110-6)

# %% [markdown]
# #### Correct complex formation IDs if they contain lipoproteins

# %%
# Bsub m-model doest not have murein

# %% [markdown]
# -----
# ## Part 7: Set keffs
#
# Either entirely based on SASA or using fit keffs from [Ebrahim et al 2016](https://www.ncbi.nlm.nih.gov/pubmed/27782110?dopt=Abstract)

# %%
# # Set keffs to sasa fluxes centered around 65.
# me.set_SASA_keffs(65)

# %%
## Get median sasa
from cobrame.core.component import Complex
import numpy as np

sasa_list = []
for met in me.metabolites:
    cplx_sasa = 0.
    if not isinstance(met, Complex):
        continue
    MW = met.formula_weight
    if not MW:
        MW = 0
        print(met.id, ' has no formula')
    cplx_sasa += MW ** (3. / 4)
    sasa_list.append(cplx_sasa)
median_sasa = np.median(np.array(sasa_list))
# Out:
# BSU15920-MONOMER_mod_pan4p  has no formula
# BSU28500-MONOMER_mod_Oxidized  has no formula
# BSU29679-MONOMER  has no formula
# MONOMER8J2-7  has no formula
# MONOMER8J2-49  has no formula
# MONOMER8J2-60  has no formula
# MONOMER8J2-48  has no formula
# MONOMER8J2-47  has no formula
# MONOMER8J2-46  has no formula
# MONOMER8J2-45  has no formula
# MONOMER8J2-58  has no formula
# MONOMER8J2-59  has no formula
# MONOMER8J2-50  has no formula
# MONOMER8J2-52  has no formula
# MONOMER8J2-55  has no formula
# MONOMER8J2-56  has no formula
# MONOMER8J2-57  has no formula
# BSU23060-MONOMER  has no formula
# BSU07540-MONOMER  has no formula
# cobra/core/Metabolite.py:97 UserWarning: The element 'X' does not appear in the peridic table

# %%
reaction_median_keffs = pandas.read_csv(flat_files.fixpath('reaction_median_keffs.txt'), sep='\t',
                              names=['Reaction', 'Complex', 'Median_Keff'])
keff_list = []
for key, row in reaction_median_keffs.iterrows():
    reaction_id = row['Reaction']
    complex_id = row['Complex']
    median_keff = row['Median_Keff']
    
    real_reaction_id = reaction_id + ''
    
    molecular_weight = me.metabolites.get_by_id(complex_id).formula_weight
    sasa = molecular_weight ** (3./4)
    keff = sasa * median_keff / median_sasa
    
    if keff > 3000:
        keff = 3000.
    elif keff < .01:
        keff = .01
    keff_list.append(keff)
    try:
        me.reactions.get_by_id(reaction_id).keff = keff
        me.reactions.get_by_id(reaction_id).update()
    except:
        continue

# %% [markdown]
# -----
# ## Part 8: Model updates and corrections

# %%
# Add reaction subsystems from iJO to model
for rxn in ijo.reactions:
    if rxn.id in me.process_data:
        data = me.process_data.get_by_id(rxn.id)
    else:
        continue
    for r in data.parent_reactions:
        r.subsystem = rxn.subsystem

# %% [markdown]
# #### Add enzymatic coupling for "carriers"
# These are enzyme complexes that act as metabolites in a metabolic reaction (i.e. are metabolites in iJO1366)

# %%
for data in me.stoichiometric_data:
    if data.id == 'dummy_reaction':
        continue
        
    for met, value in data.stoichiometry.items():
        if not isinstance(me.metabolites.get_by_id(met), cobrame.Complex) or value > 0:
            continue
            
        subreaction_id = met + '_carrier_activity'
        if subreaction_id not in me.process_data:           
            sub = cobrame.SubreactionData(met + '_carrier_activity', me)
            sub.enzyme = met
        data.subreactions[subreaction_id] = abs(value)

# %% [markdown]
# ----
# ## Part 9: Update and save

# %%
me.reactions.biomass_dilution.objective_coefficient = 1.
me.reactions.EX_glc__D_e.lower_bound = -1000
me.reactions.EX_o2_e.lower_bound = -1000
me.ngam = 9.
me.gam = 105.053483
me.unmodeled_protein_fraction = .36

me.reactions.BIOMASS_BS_10_FWD_CPLX_dummy.lower_bound = 0
me.reactions.BIOMASS_BS_10_FWD_CPLX_dummy.upper_bound = 0
me.reactions.ATPM_FWD_CPLX_dummy.lower_bound = 0
me.reactions.ATPM_FWD_CPLX_dummy.upper_bound = 0

me.metabolites.get_by_id('mn2_c').formula = 'Mn2'
me.metabolites.get_by_id('mg2_c').formula = 'Mg2'
me.metabolites.get_by_id('ca2_c').formula = 'Ca2'
me.metabolites.get_by_id('cu2_c').formula = 'Cu2'

# %%
me.update()
# Out:
# Created <Metabolite Oxidized_c at 0x7f7a252dbd30> in <ComplexFormation formation_BSU33480-MONOMER_mod_Oxidized at 0x7f7a1675b940>
# /home/jt/UCSD/cobrame-master/cobrame/core/processdata.py:256 UserWarning: met (Oxidized_c) does not have formula

# %%
me.prune()

# %% [markdown]
# ### Add remaining complex formulas and compartments to model

# %%
# Update a second time to incorporate all of the metabolite formulas corectly
for r in me.reactions.query('formation_'):
    r.update()

# Update complex formulas
df = pandas.read_table(join(flat_files.ecoli_files_dir, 'modification.txt'),
                            names=['mod', 'formula','na'])
df = df.drop('na', axis=1).set_index('mod').dropna(how='any')
modification_formulas = df.T.to_dict()
formulas.add_remaining_complex_formulas(me, modification_formulas)

# Update reactions affected by formula update 
for r in me.reactions.query('_mod_lipo'):
    r.update()
for r in me.reactions.query('_mod_glycyl'):
    r.update()
    
# add metabolite compartments
compartments.add_compartments_to_model(me)

# %% [markdown]
# ### Remaining fields

# %%
##
current_gene_ids = [gene.id for gene in me.genes]
for met in me.metabolites:
    met_id = met.id
    if 'protein_BSU' in met_id:
        gene_id = met_id.split('_')[1]
        if gene_id and gene_id not in current_gene_ids:
            try:
                print(gene_id)
                gene = cobra.Gene(gene_id)
                me.genes.append(gene)
            except:
                pass

##
me.reactions.BIOMASS_BS_10_FWD_CPLX_dummy.lower_bound = 0
me.reactions.BIOMASS_BS_10_FWD_CPLX_dummy.upper_bound = 0
me.reactions.ATPM_FWD_CPLX_dummy.lower_bound = 0
me.reactions.ATPM_FWD_CPLX_dummy.upper_bound = 0

## Homogenize exchange reactions
for rxn in me.reactions:
    if 'EX_' in rxn.id:
        try:
            lb = ijo.reactions.get_by_id(rxn.id).lower_bound
            ub = ijo.reactions.get_by_id(rxn.id).upper_bound
            rxn.lower_bound = lb
            rxn.upper_bound = ub
        except:
            print(rxn.id, 'not in m_model')
            
## These exchange reactions need to be opened
mets = ['mn2_e','zn2_e','cobalt2_e']
for met_id in mets:
    r = me.reactions.get_by_id('EX_'+met_id)
    r.lower_bound = -1000
    r.upper_bound = 0
# Out:
# BSU00090
# BSU00110
# BSU00120
# BSU00130
# BSU00140
# BSU00150
# BSU00180
# BSU00270
# BSU00280
# BSU00380
# BSU00410
# BSU00460
# BSU00500
# BSU00510
# BSU00550
# BSU00680
# BSU00730
# BSU00740
# BSU00750
# BSU00760
# BSU00770
# BSU00780
# BSU00790
# BSU00810
# BSU00820
# BSU00900
# BSU00910
# BSU00930
# BSU00940
# BSU00980
# BSU00990
# BSU01000
# BSU01010
# BSU01020
# BSU01030
# BSU01040
# BSU01050
# BSU01070
# BSU01080
# BSU01100
# BSU01110
# BSU01120
# BSU01130
# BSU01150
# BSU01160
# BSU01170
# BSU01180
# BSU01190
# BSU01200
# BSU01210
# BSU01220
# BSU01230
# BSU01240
# BSU01250
# BSU01260
# BSU01270
# BSU01280
# BSU01290
# BSU01300
# BSU01310
# BSU01320
# BSU01330
# BSU01340
# BSU01350
# BSU01360
# BSU01370
# BSU01380
# BSU01390
# BSU01400
# BSU01410
# BSU01420
# BSU01430
# BSU01440
# BSU01490
# BSU01500
# BSU01530
# BSU01580
# BSU01610
# BSU01620
# BSU01630
# BSU01680
# BSU01730
# BSU01770
# BSU01780
# BSU02090
# BSU02130
# BSU02140
# BSU02230
# BSU02270
# BSU02290
# BSU02340
# BSU02350
# BSU02360
# BSU02390
# BSU02400
# BSU02420
# BSU02430
# BSU02460
# BSU02480
# BSU02490
# BSU02510
# BSU02630
# BSU02640
# BSU02750
# BSU02760
# BSU02850
# BSU02860
# BSU02870
# BSU02980
# BSU02990
# BSU03000
# BSU03010
# BSU03040
# BSU03050
# BSU03060
# BSU03070
# BSU03130
# BSU03150
# BSU03200
# BSU03220
# BSU03270
# BSU03280
# BSU03290
# BSU03300
# BSU03310
# BSU03320
# BSU03330
# BSU03790
# BSU03800
# BSU03810
# BSU03820
# BSU03830
# BSU03860
# BSU03900
# BSU03910
# BSU03930
# BSU03950
# BSU03981
# BSU03990
# BSU04000
# BSU04030
# BSU04340
# BSU04360
# BSU04470
# BSU04520
# BSU04560
# BSU04570
# BSU04620
# BSU04640
# BSU04730
# BSU04740
# BSU05340
# BSU05740
# BSU05810
# BSU05820
# BSU05830
# BSU05860
# BSU05900
# BSU05980
# BSU05990
# BSU06020
# BSU06030
# BSU06150
# BSU06160
# BSU06170
# BSU06230
# BSU06240
# BSU06310
# BSU06360
# BSU06370
# BSU06420
# BSU06430
# BSU06440
# BSU06450
# BSU06470
# BSU06480
# BSU06490
# BSU06500
# BSU06510
# BSU06520
# BSU06530
# BSU06660
# BSU06670
# BSU06680
# BSU06690
# BSU06730
# BSU06970
# BSU06980
# BSU06990
# BSU07490
# BSU07500
# BSU07510
# BSU07520
# BSU07570
# BSU07610
# BSU07700
# BSU07800
# BSU07810
# BSU07830
# BSU07840
# BSU07920
# BSU07990
# BSU08000
# BSU08030
# BSU08060
# BSU08070
# BSU08180
# BSU08200
# BSU08440
# BSU08450
# BSU08460
# BSU08650
# BSU08710
# BSU08790
# BSU08820
# BSU08830
# BSU08840
# BSU08850
# BSU08860
# BSU09130
# BSU09240
# BSU09280
# BSU09290
# BSU09300
# BSU09310
# BSU09410
# BSU09440
# BSU09520
# BSU09530
# BSU09540
# BSU09680
# BSU09840
# BSU09850
# BSU10010
# BSU10020
# BSU10120
# BSU10130
# BSU10140
# BSU10170
# BSU10220
# BSU10270
# BSU10360
# BSU10520
# BSU10790
# BSU10870
# BSU11010
# BSU11190
# BSU11200
# BSU11210
# BSU11220
# BSU11230
# BSU11240
# BSU11250
# BSU11330
# BSU11340
# BSU11420
# BSU11610
# BSU11640
# BSU11650
# BSU11670
# BSU11710
# BSU11720
# BSU11870
# BSU11880
# BSU12010
# BSU12020
# BSU12080
# BSU12160
# BSU12290
# BSU12300
# BSU12330
# BSU12340
# BSU12360
# BSU12380
# BSU12390
# BSU12840
# BSU12910
# BSU12920
# BSU12930
# BSU12940
# BSU12950
# BSU12960
# BSU13010
# BSU13110
# BSU13120
# BSU13130
# BSU13170
# BSU13180
# BSU13300
# BSU13450
# BSU13550
# BSU13560
# BSU13580
# BSU13590
# BSU13600
# BSU13610
# BSU13620
# BSU13730
# BSU13850
# BSU13890
# BSU13900
# BSU13910
# BSU13960
# BSU14000
# BSU14180
# BSU14190
# BSU14390
# BSU14400
# BSU14520
# BSU14530
# BSU14540
# BSU14580
# BSU14590
# BSU14600
# BSU14610
# BSU14630
# BSU14670
# BSU14730
# BSU14830
# BSU14860
# BSU14870
# BSU14880
# BSU14890
# BSU14900
# BSU14910
# BSU14920
# BSU15020
# BSU15080
# BSU15110
# BSU15140
# BSU15180
# BSU15190
# BSU15200
# BSU15220
# BSU15230
# BSU15320
# BSU15350
# BSU15430
# BSU15480
# BSU15490
# BSU15500
# BSU15510
# BSU15520
# BSU15530
# BSU15540
# BSU15550
# BSU15560
# BSU15570
# BSU15580
# BSU15590
# BSU15600
# BSU15610
# BSU15620
# BSU15630
# BSU15650
# BSU15680
# BSU15690
# BSU15700
# BSU15720
# BSU15730
# BSU15750
# BSU15790
# BSU15820
# BSU15850
# BSU15860
# BSU15900
# BSU15910
# BSU15920
# BSU15930
# BSU15980
# BSU15990
# BSU16020
# BSU16040
# BSU16090
# BSU16100
# BSU16470
# BSU16490
# BSU16500
# BSU16510
# BSU16520
# BSU16530
# BSU16540
# BSU16550
# BSU16570
# BSU16600
# BSU16630
# BSU16650
# BSU16670
# BSU16680
# BSU16690
# BSU16730
# BSU16740
# BSU16750
# BSU16760
# BSU16770
# BSU16780
# BSU16920
# BSU16960
# BSU16990
# BSU17000
# BSU17150
# BSU17380
# BSU17390
# BSU17410
# BSU17460
# BSU17600
# BSU17610
# BSU17660
# BSU17680
# BSU17710
# BSU17890
# BSU18000
# BSU18120
# BSU18210
# BSU18220
# BSU18230
# BSU18250
# BSU18260
# BSU18410
# BSU18440
# BSU18450
# BSU18470
# BSU18480
# BSU18540
# BSU18570
# BSU18670
# BSU18800
# BSU18830
# BSU19230
# BSU19310
# BSU19350
# BSU19360
# BSU19370
# BSU19520
# BSU19580
# BSU19630
# BSU19690
# BSU19710
# BSU19800
# BSU20020
# BSU20250
# BSU21680
# BSU21690
# BSU21770
# BSU21810
# BSU21820
# BSU21870
# BSU21900
# BSU21910
# BSU21920
# BSU22060
# BSU22070
# BSU22090
# BSU22100
# BSU22110
# BSU22130
# BSU22140
# BSU22360
# BSU22370
# BSU22410
# BSU22420
# BSU22430
# BSU22440
# BSU22480
# BSU22490
# BSU22540
# BSU22550
# BSU22560
# BSU22600
# BSU22610
# BSU22620
# BSU22630
# BSU22640
# BSU22650
# BSU22660
# BSU22670
# BSU22680
# BSU22690
# BSU22700
# BSU22710
# BSU22730
# BSU22740
# BSU22750
# BSU22760
# BSU22780
# BSU22830
# BSU22870
# BSU22880
# BSU22890
# BSU22960
# BSU23050
# BSU23070
# BSU23080
# BSU23100
# BSU23250
# BSU23260
# BSU23270
# BSU23280
# BSU23380
# BSU23450
# BSU23490
# BSU23500
# BSU23560
# BSU23570
# BSU23580
# BSU23610
# BSU23760
# BSU23770
# BSU23800
# BSU23840
# BSU23850
# BSU23860
# BSU23920
# BSU23960
# BSU23970
# BSU23980
# BSU24030
# BSU24040
# BSU24050
# BSU24060
# BSU24070
# BSU24080
# BSU24090
# BSU24120
# BSU24130
# BSU24140
# BSU24150
# BSU24160
# BSU24170
# BSU24270
# BSU24280
# BSU24310
# BSU24340
# BSU24350
# BSU24740
# BSU24850
# BSU24900
# BSU24950
# BSU24960
# BSU24970
# BSU24980
# BSU24990
# BSU25020
# BSU25070
# BSU25160
# BSU25200
# BSU25260
# BSU25270
# BSU25290
# BSU25300
# BSU25310
# BSU25410
# BSU25420
# BSU25500
# BSU25550
# BSU25580
# BSU25640
# BSU25660
# BSU25710
# BSU25760
# BSU25790
# BSU25900
# BSU26390
# BSU26590
# BSU26600
# BSU26640
# BSU26650
# BSU26690
# BSU26810
# BSU26860
# BSU26970
# BSU27010
# BSU27040
# BSU27050
# BSU27060
# BSU27070
# BSU27120
# BSU27200
# BSU27220
# BSU27250
# BSU27260
# BSU27270
# BSU27320
# BSU27330
# BSU27410
# BSU27430
# BSU27440
# BSU27450
# BSU27460
# BSU27550
# BSU27560
# BSU27600
# BSU27610
# BSU27650
# BSU27810
# BSU27850
# BSU27860
# BSU27870
# BSU27900
# BSU27910
# BSU27940
# BSU27960
# BSU28080
# BSU28090
# BSU28120
# BSU28130
# BSU28140
# BSU28150
# BSU28230
# BSU28250
# BSU28260
# BSU28270
# BSU28280
# BSU28290
# BSU28300
# BSU28310
# BSU28370
# BSU28390
# BSU28430
# BSU28440
# BSU28450
# BSU28470
# BSU28500
# BSU28510
# BSU28540
# BSU28560
# BSU28630
# BSU28640
# BSU28680
# BSU28720
# BSU28730
# BSU28740
# BSU28750
# BSU28780
# BSU28790
# BSU28800
# BSU28850
# BSU28860
# BSU28870
# BSU28900
# BSU28910
# BSU28950
# BSU29010
# BSU29020
# BSU29050
# BSU29060
# BSU29120
# BSU29130
# BSU29140
# BSU29180
# BSU29190
# BSU29200
# BSU29210
# BSU29220
# BSU29300
# BSU29340
# BSU29350
# BSU29360
# BSU29370
# BSU29380
# BSU29440
# BSU29450
# BSU29470
# BSU29600
# BSU29620
# BSU29660
# BSU29670
# BSU29680
# BSU29750
# BSU29790
# BSU29990
# BSU30070
# BSU30200
# BSU30210
# BSU30220
# BSU30230
# BSU30240
# BSU30300
# BSU30320
# BSU30410
# BSU30420
# BSU30430
# BSU30440
# BSU30450
# BSU30530
# BSU30540
# BSU30550
# BSU30560
# BSU30690
# BSU30740
# BSU30750
# BSU30760
# BSU30770
# BSU30780
# BSU30790
# BSU30800
# BSU30820
# BSU30830
# BSU30870
# BSU30940
# BSU30950
# BSU30960
# BSU30970
# BSU30980
# BSU31050
# BSU31060
# BSU31090
# BSU31100
# BSU31150
# BSU31180
# BSU31200
# BSU31322
# BSU31350
# BSU31400
# BSU31580
# BSU31600
# BSU31610
# BSU31620
# BSU31630
# BSU31640
# BSU31650
# BSU31660
# BSU31750
# BSU31760
# BSU31930
# BSU31970
# BSU31980
# BSU31990
# BSU32000
# BSU32100
# BSU32110
# BSU32130
# BSU32170
# BSU32180
# BSU32200
# BSU32240
# BSU32250
# BSU32260
# BSU32410
# BSU32430
# BSU32440
# BSU32450
# BSU32460
# BSU32470
# BSU32480
# BSU32490
# BSU32500
# BSU32510
# BSU32680
# BSU32820
# BSU32830
# BSU32840
# BSU33040
# BSU33160
# BSU33170
# BSU33180
# BSU33240
# BSU33290
# BSU33300
# BSU33310
# BSU33330
# BSU33370
# BSU33380
# BSU33390
# BSU33400
# BSU33420
# BSU33430
# BSU33440
# BSU33490
# BSU33500
# BSU33510
# BSU33630
# BSU33700
# BSU33710
# BSU33720
# BSU33730
# BSU33800
# BSU33810
# BSU33820
# BSU33830
# BSU33900
# BSU33910
# BSU33920
# BSU33930
# BSU33940
# BSU33960
# BSU34130
# BSU34190
# BSU34200
# BSU34550
# BSU34560
# BSU34570
# BSU34590
# BSU34600
# BSU34610
# BSU34660
# BSU34790
# BSU34860
# BSU34870
# BSU34880
# BSU34890
# BSU34900
# BSU34910
# BSU34920
# BSU35010
# BSU35020
# BSU35290
# BSU35300
# BSU35530
# BSU35540
# BSU35550
# BSU35570
# BSU35580
# BSU35590
# BSU35600
# BSU35609
# BSU35620
# BSU35660
# BSU35670
# BSU35680
# BSU35690
# BSU35700
# BSU35710
# BSU35720
# BSU35730
# BSU35740
# BSU35750
# BSU35760
# BSU35780
# BSU35790
# BSU35920
# BSU35930
# BSU35940
# BSU35950
# BSU35960
# BSU36000
# BSU36010
# BSU36030
# BSU36120
# BSU36130
# BSU36370
# BSU36470
# BSU36510
# BSU36590
# BSU36640
# BSU36650
# BSU36660
# BSU36710
# BSU36760
# BSU36800
# BSU36810
# BSU36820
# BSU36830
# BSU36840
# BSU36850
# BSU36860
# BSU36870
# BSU36880
# BSU36890
# BSU36900
# BSU36920
# BSU37010
# BSU37060
# BSU37070
# BSU37080
# BSU37100
# BSU37110
# BSU37120
# BSU37150
# BSU37160
# BSU37170
# BSU37190
# BSU37240
# BSU37320
# BSU37330
# BSU37490
# BSU37500
# BSU37660
# BSU37710
# BSU37760
# BSU37780
# BSU37790
# BSU38020
# BSU38040
# BSU38050
# BSU38060
# BSU38110
# BSU38140
# BSU38150
# BSU38160
# BSU38170
# BSU38190
# BSU38200
# BSU38240
# BSU38260
# BSU38270
# BSU38280
# BSU38290
# BSU38300
# BSU38390
# BSU38490
# BSU38500
# BSU38510
# BSU38520
# BSU38530
# BSU38550
# BSU38560
# BSU38570
# BSU38580
# BSU38590
# BSU38630
# BSU38700
# BSU38710
# BSU38750
# BSU38760
# BSU38770
# BSU38830
# BSU38860
# BSU38980
# BSU38990
# BSU39020
# BSU39050
# BSU39060
# BSU39260
# BSU39270
# BSU39350
# BSU39360
# BSU39370
# BSU39380
# BSU39390
# BSU39400
# BSU39410
# BSU39420
# BSU39450
# BSU39540
# BSU39610
# BSU39670
# BSU39700
# BSU39710
# BSU39720
# BSU39730
# BSU39740
# BSU39750
# BSU39760
# BSU39780
# BSU39860
# BSU39920
# BSU39980
# BSU40040
# BSU40060
# BSU40070
# BSU40110
# BSU40190
# BSU40320
# BSU40330
# BSU40340
# BSU40420
# BSU40500
# BSU40550
# BSU40850
# BSU40890
# BSU40910
# BSU41050
# BSU41060
# BSU01000
# BSU01360
# BSU01580
# BSU01610
# BSU01620
# BSU01630
# BSU02140
# BSU02270
# BSU02290
# BSU02340
# BSU02400
# BSU02420
# BSU02480
# BSU02630
# BSU02640
# BSU02980
# BSU02990
# BSU03000
# BSU03040
# BSU03060
# BSU03070
# BSU03220
# BSU03330
# BSU03950
# BSU04360
# BSU04470
# BSU05340
# BSU05980
# BSU05990
# BSU06160
# BSU06230
# BSU06310
# BSU06370
# BSU06660
# BSU07490
# BSU07500
# BSU07510
# BSU07520
# BSU07570
# BSU07610
# BSU07840
# BSU07920
# BSU08000
# BSU08830
# BSU08840
# BSU08850
# BSU09130
# BSU09280
# BSU09540
# BSU09680
# BSU09850
# BSU10010
# BSU10220
# BSU10520
# BSU10870
# BSU11640
# BSU12010
# BSU12080
# BSU12360
# BSU12840
# BSU12930
# BSU12940
# BSU12950
# BSU12960
# BSU13180
# BSU13300
# BSU13850
# BSU13890
# BSU14400
# BSU14870
# BSU14880
# BSU14890
# BSU14900
# BSU14910
# BSU14920
# BSU15190
# BSU15220
# BSU15480
# BSU15580
# BSU15650
# BSU16540
# BSU16920
# BSU16960
# BSU17710
# BSU18120
# BSU18410
# BSU18540
# BSU18670
# BSU18800
# BSU19350
# BSU19520
# BSU19580
# BSU19800
# BSU21920
# BSU22060
# BSU22090
# BSU23050
# BSU23560
# BSU24740
# BSU24950
# BSU24960
# BSU24970
# BSU24980
# BSU24990
# BSU25290
# BSU25310
# BSU25420
# BSU25790
# BSU26590
# BSU26640
# BSU26650
# BSU26690
# BSU26860
# BSU27200
# BSU27430
# BSU27440
# BSU27450
# BSU27460
# BSU27600
# BSU27650
# BSU27810
# BSU28430
# BSU28440
# BSU28450
# BSU28870
# BSU28900
# BSU28910
# BSU29340
# BSU29350
# BSU29360
# BSU29370
# BSU29380
# BSU29600
# BSU29990
# BSU30070
# BSU30530
# BSU30740
# BSU30750
# BSU30760
# BSU30770
# BSU31090
# BSU31100
# BSU31150
# BSU31322
# BSU31580
# BSU31600
# BSU31610
# BSU31620
# BSU31630
# BSU31640
# BSU31650
# BSU31660
# BSU32180
# BSU32430
# BSU32440
# BSU33170
# BSU33240
# BSU33330
# BSU33420
# BSU33490
# BSU33500
# BSU33630
# BSU33700
# BSU33710
# BSU33720
# BSU33730
# BSU33800
# BSU33810
# BSU33820
# BSU33830
# BSU33900
# BSU33960
# BSU34190
# BSU34570
# BSU34590
# BSU34600
# BSU34610
# BSU34660
# BSU35300
# BSU35780
# BSU36030
# BSU36120
# BSU36130
# BSU36470
# BSU36510
# BSU36590
# BSU37190
# BSU37240
# BSU37320
# BSU37760
# BSU38060
# BSU38140
# BSU38150
# BSU38160
# BSU38170
# BSU38240
# BSU38490
# BSU38710
# BSU38750
# BSU38760
# BSU38770
# BSU39020
# BSU39060
# BSU39390
# BSU39410
# BSU39450
# BSU39710
# BSU40070
# BSU40330
# EX_4fe4s_e not in m_model
# EX_2fe2s_e not in m_model
# EX_udcpp_e not in m_model
# EX_pydx5p_e not in m_model
# EX_3fe4s_e not in m_model
# EX_cl_e not in m_model
# EX_sheme_e not in m_model
# EX_cu_e not in m_model
# EX_bmocogdp_e not in m_model
# EX_dpm_e not in m_model
# EX_thmpp_e not in m_model

# %% [markdown]
# ## New fixes

# %%
# Feb 12, 2020
# Model was synthesizing extra lipids to compensate and reach maximum growth rate.
# Fix: Set lb = ub = mass fraction of lipids
rxns = get_reactions_of_met(me,'lipid_biomass', s=1, verbose=False)
for rxn in rxns:
    rxn.upper_bound = mu
_=get_reactions_of_met(me,'lipid_biomass', s=1, verbose=True)
# Out:
# ( Demand_d12dg_BS_c mu mu ) 	 0.00011 d12dg_BS_c --> 0.0097263716968 lipid_biomass
# ( Demand_lipo4_24_BS_c mu mu ) 	 1.5e-05 lipo4_24_BS_c --> 0.0068361414492 lipid_biomass
# ( Demand_t12dg_BS_c mu mu ) 	 6.6e-05 t12dg_BS_c --> 0.006905950978080001 lipid_biomass
# ( Demand_gtca1_45_BS_c mu mu ) 	 0.003624 gtca1_45_BS_c --> 0.026722062249264 lipid_biomass
# ( Demand_lipo3_24_BS_c mu mu ) 	 1.8e-05 lipo3_24_BS_c --> 0.01205219511504 lipid_biomass
# ( Demand_m12dg_BS_c mu mu ) 	 8.6e-05 m12dg_BS_c --> 0.00620984507568 lipid_biomass
# ( Demand_lysylpgly_BS_c mu mu ) 	 2.2e-05 lysylpgly_BS_c --> 0.0018527632855599998 lipid_biomass
# ( Demand_pgly_BS_c mu mu ) 	 0.000176 pgly_BS_c --> 0.012548534412479996 lipid_biomass
# ( Demand_lipo2_24_BS_c mu mu ) 	 6e-06 lipo2_24_BS_c --> 0.005660428867679999 lipid_biomass
# ( Demand_gtca2_45_BS_c mu mu ) 	 0.002347 gtca2_45_BS_c --> 0.026715503385342003 lipid_biomass
# ( Demand_cdlp_BS_c mu mu ) 	 5e-06 cdlp_BS_c --> 0.0006669379998 lipid_biomass
# ( Demand_lipo1_24_BS_c mu mu ) 	 7e-06 lipo1_24_BS_c --> 0.00591416142296 lipid_biomass
# ( Demand_tcam_BS_c mu mu ) 	 0.003112 tcam_BS_c --> 0.04316222890296 lipid_biomass
# ( Demand_gtca3_45_BS_c mu mu ) 	 0.001819 gtca3_45_BS_c --> 0.026717435194354 lipid_biomass

# %%
solve_me_model(me, max_mu = 0.5, min_mu = .05, using_soplex=False, precision = 1e-6)
# Out:
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 129.031870 seconds
# Finished substituting S,lb,ub in 3.939861 seconds
# Finished makeME_LP in 0.750986 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 3.868840 seconds
# Finished makeME_LP in 0.740372 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 3.860616 seconds
# Finished makeME_LP in 0.753149 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0625 0.0625 0.125 0.0625 optimal
# Finished substituting S,lb,ub in 3.993324 seconds
# Finished makeME_LP in 0.749623 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.09375 0.09375 0.125 0.09375 optimal
# Finished substituting S,lb,ub in 3.844184 seconds
# Finished makeME_LP in 0.747095 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.09375 0.09375 0.109375 0.109375 1
# Finished substituting S,lb,ub in 3.837456 seconds
# Finished makeME_LP in 0.743103 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.1015625 0.1015625 0.109375 0.1015625 optimal
# Finished substituting S,lb,ub in 3.830336 seconds
# Finished makeME_LP in 0.751194 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.1015625 0.1015625 0.10546875 0.10546875 1
# Finished substituting S,lb,ub in 3.809070 seconds
# Finished makeME_LP in 0.752721 seconds
# Getting MINOS parameters from ME_NLP...
# 8 0.1015625 0.1015625 0.103515625 0.103515625 1
# Finished substituting S,lb,ub in 3.792685 seconds
# Finished makeME_LP in 0.749441 seconds
# Getting MINOS parameters from ME_NLP...
# 9 0.1015625 0.1015625 0.1025390625 0.1025390625 1
# Finished substituting S,lb,ub in 3.818250 seconds
# Finished makeME_LP in 0.750324 seconds
# Getting MINOS parameters from ME_NLP...
# 10 0.1015625 0.1015625 0.10205078125 0.10205078125 1
# Finished substituting S,lb,ub in 3.801661 seconds
# Finished makeME_LP in 0.749154 seconds
# Getting MINOS parameters from ME_NLP...
# 11 0.1015625 0.1015625 0.101806640625 0.101806640625 1
# Finished substituting S,lb,ub in 3.839734 seconds
# Finished makeME_LP in 0.747543 seconds
# Getting MINOS parameters from ME_NLP...
# 12 0.1016845703125 0.1016845703125 0.101806640625 0.1016845703125 optimal
# Finished substituting S,lb,ub in 3.832328 seconds
# Finished makeME_LP in 0.745039 seconds
# Getting MINOS parameters from ME_NLP...
# 13 0.1016845703125 0.1016845703125 0.10174560546875 0.10174560546875 1
# Finished substituting S,lb,ub in 3.815971 seconds
# Finished makeME_LP in 0.750287 seconds
# Getting MINOS parameters from ME_NLP...
# 14 0.1016845703125 0.1016845703125 0.101715087890625 0.101715087890625 1
# Finished substituting S,lb,ub in 3.827307 seconds
# Finished makeME_LP in 0.747546 seconds
# Getting MINOS parameters from ME_NLP...
# 15 0.1016845703125 0.1016845703125 0.1016998291015625 0.1016998291015625 1
# Finished substituting S,lb,ub in 3.808449 seconds
# Finished makeME_LP in 0.738556 seconds
# Getting MINOS parameters from ME_NLP...
# 16 0.10169219970703125 0.10169219970703125 0.1016998291015625 0.10169219970703125 optimal
# Finished substituting S,lb,ub in 3.782988 seconds
# Finished makeME_LP in 0.743606 seconds
# Getting MINOS parameters from ME_NLP...
# 17 0.10169601440429688 0.10169601440429688 0.1016998291015625 0.10169601440429688 optimal
# Finished substituting S,lb,ub in 3.787688 seconds
# Finished makeME_LP in 0.745930 seconds
# Getting MINOS parameters from ME_NLP...
# 18 0.10169792175292969 0.10169792175292969 0.1016998291015625 0.10169792175292969 optimal
# Finished substituting S,lb,ub in 3.773679 seconds
# Finished makeME_LP in 0.739723 seconds
# Getting MINOS parameters from ME_NLP...
# 19 0.1016988754272461 0.1016988754272461 0.1016998291015625 0.1016988754272461 optimal
# Bisection done in 417.759 seconds

# %%
with open("./me_models/solution.pickle", "wb") as outfile:
    pickle.dump(me, outfile)

# %%
with open("./me_models/solution.pickle", "rb") as outfile:
    me = pickle.load(outfile)

# %%
with open("./me_models/iJL1678b.pickle", "rb") as outfile:
    ecome = pickle.load(outfile)

# %%
# save_json_me_model(me, './me_models/iBS.json')

# %%
for r in me.reactions:
    if 'biomass' in r.id:
        print(r.id,r.reaction)

# %%
import matplotlib.pyplot as plt
type_count = {}
for r in me.reactions:
    rxn_type = str(type(r))
    rxn_type = rxn_type.split('.')[-1].split("'")[0].split('Reaction')[0]
    if rxn_type =='ME':
        rxn_type = 'ExchangeDilution'
    if rxn_type not in type_count.keys():
        type_count[rxn_type] = 0
    type_count[rxn_type] += 1
pd.DataFrame.from_dict({'count':type_count}).plot.bar(legend=False)
plt.ylabel('Count')
plt.title('Reaction breakdown')

# %%
import matplotlib.pyplot as plt
type_count = {}
for r in me.metabolites:
    rxn_type = str(type(r))
    rxn_type = rxn_type.split('.')[-1].split("'")[0]
    if rxn_type not in type_count.keys():
        type_count[rxn_type] = 0
    type_count[rxn_type] += 1
pd.DataFrame.from_dict({'count':type_count}).plot.bar(legend=False)
plt.ylabel('Count')
plt.title('Metabolite breakdown')

# %%
solve_me_model(me, max_mu = 0.5, min_mu = .05, using_soplex=False, precision = 1e-2)

# %%
me.reactions.get_by_id('ASPt2r_FWD_CPLX_dummy').reaction

# %%
#mets = ['cl', 'sheme', 'mg2', 'ni2', 'thmpp', 'cu', 'nad', 'ca2', 'fmn', 'zn2', 'pydx5p', 'pi', 'pheme',
# 'bmocogdp', '4fe4s', 'mn2', 'cbl1', 'cu2', 'k', 'cobalt2', '2fe2s', 'fe2']
mets = ['glc__D']
met_ids = [met+'_c' for met in mets]

# %%
gap_mets = brute_force_check(me,met_ids,'biomass_dilution',0.02)

# %%
me_ = me.copy()

# %%
from qminospy import me2

# %%
# This adds exchange reactions for metabolites not contained in iJO1366
# Some of these cannot be produced by the model so they are added here
exchange_list = ['4fe4s_c','2fe2s_c','udcpp_c','pydx5p_c','3fe4s_c','cl_c','sheme_c','cu_c','mn2_c',
                 'bmocogdp_c','dpm_c','thmpp_c','zn2_c','cbl1_c','cobalt2_c']
transport_candidates = {}
bsub_ecoli_blast = pd.read_csv('./building_data/blast_out_bsub_as_ref.txt',sep='\t',index_col=2)
for met_id in exchange_list:   
    # Identify or create metabolites
    if hasattr(me.metabolites,met_id):
        met = me.metabolites.get_by_id(met_id)
    else:
        met = cobrame.Metabolite(met_id)
    met_e_id = re.sub('_.','_e',met_id)
    if hasattr(me.metabolites,met_e_id):
        met_e = me.metabolites.get_by_id(met_e_id)
    else:
        met_e = cobrame.Metabolite(met_e_id)
        
    # Identify or create exchange reaction
    ex_id = 'EX_{}'.format(met_e_id)
    if hasattr(me.reactions,ex_id):
        ex_r = me.reactions.get_by_id(ex_id)
    else:
        ex_r = cobrame.MEReaction(ex_id)
        ex_r.add_metabolites({met_e:-1})
        me.add_reaction(ex_r)
    ex_r.upper_bound = 0 # Avoid secretion of this metabolites. These reactions are
                         # only meant to supply cofactors for which no biosynthetic 
                         # pathway has been defined in the model.
    ex_r.lower_bound = -1000
    
    # Identify or create transport reaction. Available transport reactions in model?
    met_prod_rxns = [rxn.id for rxn in get_reactions_of_met(m_model,met.id,s=1,verbose=0)]
    met_e_cons_rxns = [rxn.id for rxn in get_reactions_of_met(m_model,met_e.id,s=-1,verbose=0)]
    transport = list(set(met_prod_rxns)&set(met_e_cons_rxns))
    ref = 'none'
    if transport:
        ref = 'bsub'
        for r in transport:
            rxn = m_model.reactions.get_by_id(r)
            rxn.lower_bound = 0
            rxn.upper_bound = 1000
            print('Found in model:',met_id,r,rxn.reaction)
    else:
        # In E. coli as template?
        transporters = []
        met_prod_rxns = [rxn.id for rxn in get_reactions_of_met(eco,re.sub('_.','_p',met.id),s=1,verbose=0)]
        met_e_cons_rxns = [rxn.id for rxn in get_reactions_of_met(eco,met_e.id,s=-1,verbose=0)]
        transport = list(set(met_prod_rxns)&set(met_e_cons_rxns))
        if transport:
            ref = 'eco'
            for r in transport:
                rxn = eco.reactions.get_by_id(r)
                transporters = [bsub_ecoli_blast.loc[gene.id]['BSUB_gene'] for gene in rxn.genes \
                                    if gene.id in bsub_ecoli_blast.index]
                if transporters:
                    transport_candidates[met_id] = transporters
                    print('Manually curate: ', met_id, transport)
                else:
                    art = 1
        else:
            art = 1
        if art:
            ## Add artificial reaction
            t_r = cobrame.MEReaction(met_id.split('_')[0].upper()+'t')
            t_r.add_metabolites({met_e:-1,met:1})
            print('Artificially added: ', met_id)
            me.add_reaction(t_r)
    #_ = get_reactions_of_met(me,met_e.id)

# %%
# This adds exchange reactions for metabolites not contained in iJO1366
# Some of these cannot be produced by the model so they are added here
exchange_list = ['4fe4s_c','2fe2s_c','udcpp_c','mn2_c','pydx5p_c','3fe4s_c','cl_c','sheme_c','cu_c',
                 'bmocogdp_c','dpm_c','thmpp_c','zn2_c','cbl1_c','cobalt2_c']

for met_id in exchange_list:
    r = cobrame.MEReaction("EX_" + met_id)
    me.add_reaction(r)
    r.reaction = met_id + " <=> "

# %% [markdown]
# ### Breakdown

# %%
def get_breakdown(me,field):
    count = {}
    for instance in getattr(me,field):
        instance_type = instance.__class__.__name__
        if instance_type not in count.keys():
            count[instance_type] = 0
        count[instance_type] += 1
    return pd.DataFrame.from_dict({'count':count})

# %%
import matplotlib.pyplot as plt
fields = ['metabolites','reactions']

lims = np.array([[0,300,800,1100],[0,1000,1300,1800]])

fig,ax = plt.subplots(2,len(fields),sharex=False)
plt.rcParams['svg.fonttype'] = 'none'
for idx,f in enumerate(fields):
    df = get_breakdown(me,f).sort_values(by='count')
    
    df.plot.bar(legend=False,figsize=(13,5),ax=ax[0,idx])
    df.plot.bar(legend=False,figsize=(13,5),ax=ax[1,idx])
    
    ax[0,idx].set_ylim(lims[idx,2], lims[idx,3])  # outliers only
    ax[1,idx].set_ylim(lims[idx,0], lims[idx,1])  # most of the data
    
    ax[0,idx].spines['bottom'].set_visible(False)
    ax[1,idx].spines['top'].set_visible(False)
    ax[0,idx].tick_params(axis='x', which='both',bottom=False)
    
    ax[0,idx].tick_params(labeltop=False)  # don't put tick labels at the top
    ax[1,idx].xaxis.tick_bottom()
    
    
    ax[0,idx].set_ylabel('Count')
    ax[0,idx].set_title(f)
fig.savefig("./analysis/figures/feature_breakdown.svg", format="SVG")

# %%
df = get_breakdown(me,fields[1])
df.sort_values(by='count').plot.bar(figsize=(6.5,5))
plt.savefig("./analysis/figures/reaction_breakdown.svg", format="SVG")

# %%
a=0
for r in me.reactions:
    instance_type = r.__class__.__name__
    if instance_type=='MEReaction' and 'DM_RNA' in r.id:
        a += 1
print(a)
# Out:
# 1082

# %%
temp = get_gene_annotation(me,m_model)
# Out:
# 100%|██████████| 4211/4211 [00:14<00:00, 287.27it/s]

# %%
i=0
for m in me.metabolites:
    if isinstance(m,cobrame.TranslatedGene):
        i+=1
print(i)
# Out:
# 965

# %%
df = get_breakdown(me,fields[0])
df.div(df.sum())
# Out:
#                      count
# Complex           0.206127
# Constraint        0.002850
# GenericComponent  0.002612
# GenerictRNA       0.014723
# Metabolite        0.237711
# ProcessedProtein  0.049632
# Ribosome          0.000237
# TranscribedGene   0.256946
# TranslatedGene    0.229162

# %%
get_reactions_of_met(me,'etoh_c')
# Out:
# ( ALCD2y_FWD_BSU26970-MONOMER 0 999999.0 ) 	 4.27350427350427e-6*mu BSU26970-MONOMER + etoh_c + nadp_c <=> acald_c + h_c + nadph_c
# ( ALCD2y_REV_BSU27010-MONOMER 0 999999.0 ) 	 2.97433526877463e-6*mu BSU27010-MONOMER + acald_c + h_c + nadph_c <=> etoh_c + nadp_c
# ( ALCD2y_FWD_BSU27010-MONOMER 0 999999.0 ) 	 2.97433526877463e-6*mu BSU27010-MONOMER + etoh_c + nadp_c <=> acald_c + h_c + nadph_c
# ( ALCD2y_REV_CPLX8J2-194 0 999999.0 ) 	 4.27350427350427e-6*mu CPLX8J2-194 + acald_c + h_c + nadph_c <=> etoh_c + nadp_c
# ( ALCD2y_FWD_CPLX8J2-194 0 999999.0 ) 	 4.27350427350427e-6*mu CPLX8J2-194 + etoh_c + nadp_c <=> acald_c + h_c + nadph_c
# ( ETOHtex_FWD_SPONT 0 1000.0 ) 	 etoh_e <=> etoh_c
# ( ALCD2y_REV_BSU26970-MONOMER 0 999999.0 ) 	 4.27350427350427e-6*mu BSU26970-MONOMER + acald_c + h_c + nadph_c <=> etoh_c + nadp_c
# [<MetabolicReaction ALCD2y_FWD_BSU26970-MONOMER at 0x7f32c5b6d400>,
#  <MetabolicReaction ALCD2y_REV_BSU27010-MONOMER at 0x7f32c5b6d710>,
#  <MetabolicReaction ALCD2y_FWD_BSU27010-MONOMER at 0x7f32c5b6d940>,
#  <MetabolicReaction ALCD2y_REV_CPLX8J2-194 at 0x7f32c5b6d5f8>,
#  <MetabolicReaction ALCD2y_FWD_CPLX8J2-194 at 0x7f32c5b6d7b8>,
#  <MetabolicReaction ETOHtex_FWD_SPONT at 0x7f32c50702e8>,
#  <MetabolicReaction ALCD2y_REV_BSU26970-MONOMER at 0x7f32c5b6d0f0>]

# %%
for m in me.metabolites:
    if 'ba' in m.name:
        print(m.id, m.name)
# Out:
# cbasp_c N-Carbamoyl-L-aspartate
# cbp_c Carbamoyl phosphate

# %%
len(me.reactions)-len(m_model.reactions)
# Out:
# 5028

# %%
m_model.reactions.BIOMASS_BS_10.reaction
# Out:
# '0.000367 10fthf_c + 0.266902 ala__L_c + 0.00467 amp_c + 0.193021 arg__L_c + 0.147987 asn__L_c + 0.148014 asp__L_c + 105.053483 atp_c + 0.003205 ca2_c + 5e-06 cdlp_BS_c + 0.000251 cdp_c + 0.001042 cmp_c + 0.038902 ctp_c + 0.05699 cys__L_c + 0.00011 d12dg_BS_c + 0.022982 datp_c + 0.01738 dctp_c + 0.017398 dgtp_c + 0.022899 dttp_c + 0.00345 fe3_c + 0.00018 gdp_c + 0.260335 gln__L_c + 0.260378 glu__L_c + 0.408288 gly_c + 0.000503 gmp_c + 0.003624 gtca1_45_BS_c + 0.002347 gtca2_45_BS_c + 0.001819 gtca3_45_BS_c + 0.062667 gtp_c + 105.0 h2o_c + 0.081739 his__L_c + 0.269905 ile__L_c + 0.706312 k_c + 0.346445 leu__L_c + 7e-06 lipo1_24_BS_c + 6e-06 lipo2_24_BS_c + 1.8e-05 lipo3_24_BS_c + 1.5e-05 lipo4_24_BS_c + 0.323093 lys__L_c + 2.2e-05 lysylpgly_BS_c + 8.6e-05 m12dg_BS_c + 0.113326 met__L_c + 0.101714 mg2_c + 0.000266 mql7_c + 0.016164 nad_c + 0.000934 nadp_c + 0.000216 nadph_c + 0.101817 peptido_BS_c + 0.000176 pgly_BS_c + 0.175939 phe__L_c + 0.000918 ppi_c + 0.160642 pro__L_c + 0.00056 psetha_BS_c + 0.216213 ser__L_c + 6.6e-05 t12dg_BS_c + 0.003112 tcam_BS_c + 0.186317 thr__L_c + 0.054336 trp__L_c + 0.110824 tyr__L_c + 0.041501 utp_c + 0.306734 val__L_c <=> 104.997414 adp_c + 105.0 h_c + 104.985613 pi_c'

# %%
get_reactions_of_met(me,'lipid_biomass')
# Out:
# ( Demand_gtca3_45_BS_c mu mu ) 	 0.001819 gtca3_45_BS_c <=> 0.026717435194354 lipid_biomass
# ( Demand_lipo3_24_BS_c mu mu ) 	 1.8e-05 lipo3_24_BS_c <=> 0.01205219511504 lipid_biomass
# ( Demand_tcam_BS_c mu mu ) 	 0.003112 tcam_BS_c <=> 0.04316222890296 lipid_biomass
# ( Demand_lipo1_24_BS_c mu mu ) 	 7e-06 lipo1_24_BS_c <=> 0.00591416142296 lipid_biomass
# ( Demand_gtca1_45_BS_c mu mu ) 	 0.003624 gtca1_45_BS_c <=> 0.026722062249264 lipid_biomass
# ( Demand_lysylpgly_BS_c mu mu ) 	 2.2e-05 lysylpgly_BS_c <=> 0.0018527632855599998 lipid_biomass
# ( Demand_cdlp_BS_c mu mu ) 	 5e-06 cdlp_BS_c <=> 0.0006669379998 lipid_biomass
# ( Demand_lipo4_24_BS_c mu mu ) 	 1.5e-05 lipo4_24_BS_c <=> 0.0068361414492 lipid_biomass
# ( Demand_gtca2_45_BS_c mu mu ) 	 0.002347 gtca2_45_BS_c <=> 0.026715503385342003 lipid_biomass
# ( Demand_lipo2_24_BS_c mu mu ) 	 6e-06 lipo2_24_BS_c <=> 0.005660428867679999 lipid_biomass
# ( Demand_d12dg_BS_c mu mu ) 	 0.00011 d12dg_BS_c <=> 0.0097263716968 lipid_biomass
# ( Demand_t12dg_BS_c mu mu ) 	 6.6e-05 t12dg_BS_c <=> 0.006905950978080001 lipid_biomass
# ( Demand_m12dg_BS_c mu mu ) 	 8.6e-05 m12dg_BS_c <=> 0.00620984507568 lipid_biomass
# ( Demand_pgly_BS_c mu mu ) 	 0.000176 pgly_BS_c <=> 0.012548534412479996 lipid_biomass
# ( lipid_biomass_to_biomass 0.0 1000.0 ) 	 lipid_biomass --> biomass
# [<SummaryVariable Demand_gtca3_45_BS_c at 0x7f32c507da20>,
#  <SummaryVariable Demand_lipo3_24_BS_c at 0x7f32c507d860>,
#  <SummaryVariable Demand_tcam_BS_c at 0x7f32c507de80>,
#  <SummaryVariable Demand_lipo1_24_BS_c at 0x7f32c507d6a0>,
#  <SummaryVariable Demand_gtca1_45_BS_c at 0x7f32c507dcc0>,
#  <SummaryVariable Demand_lysylpgly_BS_c at 0x7f32c507d4e0>,
#  <SummaryVariable Demand_cdlp_BS_c at 0x7f32c507db00>,
#  <SummaryVariable Demand_lipo4_24_BS_c at 0x7f32c507d940>,
#  <SummaryVariable Demand_gtca2_45_BS_c at 0x7f32c507df60>,
#  <SummaryVariable Demand_lipo2_24_BS_c at 0x7f32c507d780>,
#  <SummaryVariable Demand_d12dg_BS_c at 0x7f32c507dda0>,
#  <SummaryVariable Demand_t12dg_BS_c at 0x7f32c507d5c0>,
#  <SummaryVariable Demand_m12dg_BS_c at 0x7f32c5070fd0>,
#  <SummaryVariable Demand_pgly_BS_c at 0x7f32c507dbe0>,
#  <SummaryVariable lipid_biomass_to_biomass at 0x7f32ca2a67f0>]

# %%
for m in me.metabolites:
    if 'flavin' in m.name:
        print(m.id, m.name)
# Out:
# ribflvRD_c Reduced riboflavin C17H22N4O6
# ribflv_c Riboflavin C17H20N4O6
# ribflv_e Riboflavin C17H20N4O6

# %%
get_reactions_of_met(me,'BSU03040-MONOMER')
# Out:
# ( formation_BSU03040-MONOMER 0.0 1000.0 ) 	 protein_BSU03040_Inner_Membrane --> BSU03040-MONOMER
# ( AAMYL_1_FWD_BSU03040-MONOMER 0 999999.0 ) 	 1.82732695506128e-6*mu BSU03040-MONOMER + starch_e <=> dextrin_e
# [<ComplexFormation formation_BSU03040-MONOMER at 0x7f32c658fb38>,
#  <MetabolicReaction AAMYL_1_FWD_BSU03040-MONOMER at 0x7f32c5daddd8>]

# %%
# Define Models
temp = join(flat_files.ecoli_files_dir, 'iYO844.json')
clean_bsub = cobra.io.load_json_model(temp)

# %%
clean_bsub.optimize()
# Out:
# <Solution 0.12 at 0x7f32c6646cc0>

# %%
me_dict = me.get_metabolic_flux()
m_dict = clean_bsub.solution.x_dict

comparison_dict = {}
for r in me_dict:
    if r not in m_dict:
        print('Skipping {}'.format(r))
        continue
    comparison_dict[r] = {}
    comparison_dict[r]['m'] = m_dict[r]
    comparison_dict[r]['me'] = me_dict[r]
# Out:
# Skipping CU2abc1
# Skipping COBALTt5
# Skipping ETOHtex
# Skipping CBLtex
# Skipping dummy_reaction
# Skipping EX_cbl1_e
# Skipping EX_4fe4s_e
# Skipping EX_2fe2s_e
# Skipping EX_udcpp_e
# Skipping EX_pydx5p_e
# Skipping EX_3fe4s_e
# Skipping EX_cl_e
# Skipping EX_sheme_e
# Skipping EX_cu_e
# Skipping EX_bmocogdp_e
# Skipping EX_dpm_e
# Skipping EX_thmpp_e
# Skipping DM_RNA_BSU23050
# Skipping DM_RNA_BSU29190
# Skipping DM_RNA_BSU29180
# Skipping DM_RNA_BSU39670
# Skipping DM_RNA_BSU39720
# Skipping DM_RNA_BSU39700
# Skipping DM_RNA_BSU39760
# Skipping DM_RNA_BSU39710
# Skipping DM_RNA_BSU39730
# Skipping DM_RNA_BSU39740
# Skipping DM_RNA_BSU39750
# Skipping DM_RNA_BSU24310
# Skipping DM_RNA_BSU03930
# Skipping DM_RNA_BSU10270
# Skipping DM_RNA_BSU12910
# Skipping DM_RNA_BSU35660
# Skipping DM_RNA_BSU04340
# Skipping DM_RNA_BSU25200
# Skipping DM_RNA_BSU40330
# Skipping DM_RNA_BSU40340
# Skipping DM_RNA_BSU40320
# Skipping DM_RNA_BSU35620
# Skipping DM_RNA_BSU26390
# Skipping DM_RNA_BSU25760
# Skipping DM_RNA_BSU28850
# Skipping DM_RNA_BSU28870
# Skipping DM_RNA_BSU28860
# Skipping DM_RNA_BSU08450
# Skipping DM_RNA_BSU08460
# Skipping DM_RNA_BSU41060
# Skipping DM_RNA_BSU06660
# Skipping DM_RNA_BSU31350
# Skipping DM_RNA_BSU16920
# Skipping DM_RNA_BSU15990
# Skipping DM_RNA_BSU22960
# Skipping DM_RNA_BSU02090
# Skipping DM_RNA_BSU13560
# Skipping DM_RNA_BSU13550
# Skipping DM_RNA_BSU35670
# Skipping DM_RNA_BSU07830
# Skipping DM_RNA_BSU23840
# Skipping DM_RNA_BSU32450
# Skipping DM_RNA_BSU32430
# Skipping DM_RNA_BSU32440
# Skipping DM_RNA_BSU32460
# Skipping DM_RNA_BSU12020
# Skipping DM_RNA_BSU12010
# Skipping DM_RNA_BSU17890
# Skipping DM_RNA_BSU03010
# Skipping DM_RNA_BSU39410
# Skipping DM_RNA_BSU39400
# Skipping DM_RNA_BSU39420
# Skipping DM_RNA_BSU10520
# Skipping DM_RNA_BSU38200
# Skipping DM_RNA_BSU38190
# Skipping DM_RNA_BSU08440
# Skipping DM_RNA_BSU36640
# Skipping DM_RNA_BSU36650
# Skipping DM_RNA_BSU36660
# Skipping DM_RNA_BSU38580
# Skipping DM_RNA_BSU38570
# Skipping DM_RNA_BSU38560
# Skipping DM_RNA_BSU38590
# Skipping DM_RNA_BSU29990
# Skipping DM_RNA_BSU01530
# Skipping DM_RNA_BSU30550
# Skipping DM_RNA_BSU09300
# Skipping DM_RNA_BSU06230
# Skipping DM_RNA_BSU23500
# Skipping DM_RNA_BSU23490
# Skipping DM_RNA_BSU_tRNA_65
# Skipping DM_RNA_BSU_tRNA_69
# Skipping DM_RNA_BSU_tRNA_57
# Skipping DM_RNA_BSU_tRNA_61
# Skipping DM_RNA_BSU_tRNA_53
# Skipping DM_RNA_BSU_tRNA_71
# Skipping DM_RNA_BSU_tRNA_68
# Skipping DM_RNA_BSU_tRNA_56
# Skipping DM_RNA_BSU_rRNA_19
# Skipping DM_RNA_BSU_rRNA_21
# Skipping DM_RNA_BSU_tRNA_60
# Skipping DM_RNA_BSU_tRNA_55
# Skipping DM_RNA_BSU_tRNA_70
# Skipping DM_RNA_BSU_tRNA_64
# Skipping DM_RNA_BSU_tRNA_67
# Skipping DM_RNA_BSU_tRNA_72
# Skipping DM_RNA_BSU_tRNA_59
# Skipping DM_RNA_BSU_tRNA_62
# Skipping DM_RNA_BSU_tRNA_63
# Skipping DM_RNA_BSU_tRNA_52
# Skipping DM_RNA_BSU_rRNA_20
# Skipping DM_RNA_BSU_tRNA_54
# Skipping DM_RNA_BSU_tRNA_66
# Skipping DM_RNA_BSU_tRNA_58
# Skipping DM_RNA_BSU11420
# Skipping DM_RNA_BSU37070
# Skipping DM_RNA_BSU16470
# Skipping DM_RNA_BSU28630
# Skipping DM_RNA_BSU09520
# Skipping DM_RNA_BSU03000
# Skipping DM_RNA_BSU02990
# Skipping DM_RNA_BSU02980
# Skipping DM_RNA_BSU38980
# Skipping DM_RNA_BSU38990
# Skipping DM_RNA_BSU37790
# Skipping DM_RNA_BSU03330
# Skipping DM_RNA_BSU25070
# Skipping DM_RNA_BSU05810
# Skipping DM_RNA_BSU05860
# Skipping DM_RNA_BSU05830
# Skipping DM_RNA_BSU05820
# Skipping DM_RNA_BSU00150
# Skipping DM_RNA_BSU00140
# Skipping DM_RNA_BSU07920
# Skipping DM_RNA_BSU39350
# Skipping DM_RNA_BSU39390
# Skipping DM_RNA_BSU39370
# Skipping DM_RNA_BSU39380
# Skipping DM_RNA_BSU39360
# Skipping DM_RNA_BSU08060
# Skipping DM_RNA_BSU08070
# Skipping DM_RNA_BSU33440
# Skipping DM_RNA_BSU33430
# Skipping DM_RNA_BSU04000
# Skipping DM_RNA_BSU38550
# Skipping DM_RNA_BSU40060
# Skipping DM_RNA_BSU40070
# Skipping DM_RNA_BSU27430
# Skipping DM_RNA_BSU27460
# Skipping DM_RNA_BSU27450
# Skipping DM_RNA_BSU27440
# Skipping DM_RNA_BSU01070
# Skipping DM_RNA_BSU14630
# Skipping DM_RNA_BSU38710
# Skipping DM_RNA_BSU27940
# Skipping DM_RNA_BSU30540
# Skipping DM_RNA_BSU30530
# Skipping DM_RNA_BSU14390
# Skipping DM_RNA_BSU14400
# Skipping DM_RNA_BSU09290
# Skipping DM_RNA_BSU09280
# Skipping DM_RNA_BSU30950
# Skipping DM_RNA_BSU30970
# Skipping DM_RNA_BSU30980
# Skipping DM_RNA_BSU30940
# Skipping DM_RNA_BSU30960
# Skipping DM_RNA_BSU35010
# Skipping DM_RNA_BSU35020
# Skipping DM_RNA_BSU15140
# Skipping DM_RNA_BSU23100
# Skipping DM_RNA_BSU00130
# Skipping DM_RNA_BSU32830
# Skipping DM_RNA_BSU32840
# Skipping DM_RNA_BSU32820
# Skipping DM_RNA_BSU07520
# Skipping DM_RNA_BSU07510
# Skipping DM_RNA_BSU07490
# Skipping DM_RNA_BSU07500
# Skipping DM_RNA_BSU28950
# Skipping DM_RNA_BSU17460
# Skipping DM_RNA_BSU03320
# Skipping DM_RNA_BSU03300
# Skipping DM_RNA_BSU03280
# Skipping DM_RNA_BSU03310
# Skipping DM_RNA_BSU03290
# Skipping DM_RNA_BSU11720
# Skipping DM_RNA_BSU03981
# Skipping DM_RNA_BSU03990
# Skipping DM_RNA_BSU38110
# Skipping DM_RNA_BSU40420
# Skipping DM_RNA_BSU33370
# Skipping DM_RNA_BSU35720
# Skipping DM_RNA_BSU35730
# Skipping DM_RNA_BSU35740
# Skipping DM_RNA_BSU32110
# Skipping DM_RNA_BSU01620
# Skipping DM_RNA_BSU01610
# Skipping DM_RNA_BSU01630
# Skipping DM_RNA_BSU22060
# Skipping DM_RNA_BSU22070
# Skipping DM_RNA_BSU08820
# Skipping DM_RNA_BSU01780
# Skipping DM_RNA_BSU23080
# Skipping DM_RNA_BSU38770
# Skipping DM_RNA_BSU25420
# Skipping DM_RNA_BSU23450
# Skipping DM_RNA_BSU03040
# Skipping DM_RNA_BSU39050
# Skipping DM_RNA_BSU10170
# Skipping DM_RNA_BSU39540
# Skipping DM_RNA_BSU03820
# Skipping DM_RNA_BSU03810
# Skipping DM_RNA_BSU03800
# Skipping DM_RNA_BSU03830
# Skipping DM_RNA_BSU12390
# Skipping DM_RNA_BSU12330
# Skipping DM_RNA_BSU12300
# Skipping DM_RNA_BSU12340
# Skipping DM_RNA_BSU12380
# Skipping DM_RNA_BSU12360
# Skipping DM_RNA_BSU33400
# Skipping DM_RNA_BSU38290
# Skipping DM_RNA_BSU38300
# Skipping DM_RNA_BSU29660
# Skipping DM_RNA_BSU25790
# Skipping DM_RNA_BSU13170
# Skipping DM_RNA_BSU12840
# Skipping DM_RNA_BSU38630
# Skipping DM_RNA_BSU27600
# Skipping DM_RNA_BSU33820
# Skipping DM_RNA_BSU33810
# Skipping DM_RNA_BSU33800
# Skipping DM_RNA_BSU33830
# Skipping DM_RNA_BSU36470
# Skipping DM_RNA_BSU15320
# Skipping DM_RNA_BSU29620
# Skipping DM_RNA_BSU23580
# Skipping DM_RNA_BSU23570
# Skipping DM_RNA_BSU09840
# Skipping DM_RNA_BSU23860
# Skipping DM_RNA_BSU36900
# Skipping DM_RNA_BSU23280
# Skipping DM_RNA_BSU23260
# Skipping DM_RNA_BSU23270
# Skipping DM_RNA_BSU23250
# Skipping DM_RNA_BSU07570
# Skipping DM_RNA_BSU31930
# Skipping DM_RNA_BSU37500
# Skipping DM_RNA_BSU37490
# Skipping DM_RNA_BSU17610
# Skipping DM_RNA_BSU17600
# Skipping DM_RNA_BSU24340
# Skipping DM_RNA_BSU24350
# Skipping DM_RNA_BSU02270
# Skipping DM_RNA_BSU02290
# Skipping DM_RNA_BSU03790
# Skipping DM_RNA_BSU00180
# Skipping DM_RNA_BSU08200
# Skipping DM_RNA_BSU08180
# Skipping DM_RNA_BSU02230
# Skipping DM_RNA_BSU33920
# Skipping DM_RNA_BSU33910
# Skipping DM_RNA_BSU33940
# Skipping DM_RNA_BSU33930
# Skipping DM_RNA_BSU33900
# Skipping DM_RNA_BSU39860
# Skipping DM_RNA_BSU38270
# Skipping DM_RNA_BSU38260
# Skipping DM_RNA_BSU38280
# Skipping DM_RNA_BSU04030
# Skipping DM_RNA_BSU25500
# Skipping DM_RNA_BSU00500
# Skipping DM_RNA_BSU00510
# Skipping DM_RNA_BSU00380
# Skipping DM_RNA_BSU17680
# Skipping DM_RNA_BSU04470
# Skipping DM_RNA_BSU30070
# Skipping DM_RNA_BSU26690
# Skipping DM_RNA_BSU13900
# Skipping DM_RNA_BSU13890
# Skipping DM_RNA_BSU13910
# Skipping DM_RNA_BSU35780
# Skipping DM_RNA_BSU40500
# Skipping DM_RNA_BSU30560
# Skipping DM_RNA_BSU06240
# Skipping DM_RNA_BSU15110
# Skipping DM_RNA_BSU09440
# Skipping DM_RNA_BSU01770
# Skipping DM_RNA_BSU16780
# Skipping DM_RNA_BSU36890
# Skipping DM_RNA_BSU10120
# Skipping DM_RNA_BSU10140
# Skipping DM_RNA_BSU10130
# Skipping DM_RNA_BSU39020
# Skipping DM_RNA_BSU29020
# Skipping DM_RNA_BSU29010
# Skipping DM_RNA_BSU24080
# Skipping DM_RNA_BSU24050
# Skipping DM_RNA_BSU24060
# Skipping DM_RNA_BSU24040
# Skipping DM_RNA_BSU24070
# Skipping DM_RNA_BSU24030
# Skipping DM_RNA_BSU24090
# Skipping DM_RNA_BSU39450
# Skipping DM_RNA_BSU18000
# Skipping DM_RNA_BSU29380
# Skipping DM_RNA_BSU29360
# Skipping DM_RNA_BSU29340
# Skipping DM_RNA_BSU29370
# Skipping DM_RNA_BSU29300
# Skipping DM_RNA_BSU29350
# Skipping DM_RNA_BSU29130
# Skipping DM_RNA_BSU29120
# Skipping DM_RNA_BSU29140
# Skipping DM_RNA_BSU11330
# Skipping DM_RNA_BSU11340
# Skipping DM_RNA_BSU33730
# Skipping DM_RNA_BSU33720
# Skipping DM_RNA_BSU33700
# Skipping DM_RNA_BSU33710
# Skipping DM_RNA_BSU38060
# Skipping DM_RNA_BSU18670
# Skipping DM_RNA_BSU40110
# Skipping DM_RNA_BSU19580
# Skipping DM_RNA_BSU13850
# Skipping DM_RNA_BSU01730
# Skipping DM_RNA_BSU03200
# Skipping DM_RNA_BSU30750
# Skipping DM_RNA_BSU30760
# Skipping DM_RNA_BSU30740
# Skipping DM_RNA_BSU30770
# Skipping DM_RNA_BSU15230
# Skipping DM_RNA_BSU15190
# Skipping DM_RNA_BSU15180
# Skipping DM_RNA_BSU15200
# Skipping DM_RNA_BSU15220
# Skipping DM_RNA_BSU28150
# Skipping DM_RNA_BSU28130
# Skipping DM_RNA_BSU28120
# Skipping DM_RNA_BSU28140
# Skipping DM_RNA_BSU06360
# Skipping DM_RNA_BSU13120
# Skipping DM_RNA_BSU13130
# Skipping DM_RNA_BSU16630
# Skipping DM_RNA_BSU16650
# Skipping DM_RNA_BSU16600
# Skipping DM_RNA_BSU15930
# Skipping DM_RNA_BSU17150
# Skipping DM_RNA_BSU36860
# Skipping DM_RNA_BSU36820
# Skipping DM_RNA_BSU36870
# Skipping DM_RNA_BSU36810
# Skipping DM_RNA_BSU36880
# Skipping DM_RNA_BSU36800
# Skipping DM_RNA_BSU36840
# Skipping DM_RNA_BSU36850
# Skipping DM_RNA_BSU36830
# Skipping DM_RNA_BSU02760
# Skipping DM_RNA_BSU02750
# Skipping DM_RNA_BSU31750
# Skipping DM_RNA_BSU37170
# Skipping DM_RNA_BSU37160
# Skipping DM_RNA_BSU09130
# Skipping DM_RNA_BSU07700
# Skipping DM_RNA_BSU32130
# Skipping DM_RNA_BSU15910
# Skipping DM_RNA_BSU15900
# Skipping DM_RNA_BSU08030
# Skipping DM_RNA_BSU11710
# Skipping DM_RNA_BSU11650
# Skipping DM_RNA_BSU11670
# Skipping DM_RNA_BSU38040
# Skipping DM_RNA_BSU38050
# Skipping DM_RNA_BSU18210
# Skipping DM_RNA_BSU18230
# Skipping DM_RNA_BSU18250
# Skipping DM_RNA_BSU18220
# Skipping DM_RNA_BSU18260
# Skipping DM_RNA_BSU29470
# Skipping DM_RNA_BSU13600
# Skipping DM_RNA_BSU13610
# Skipping DM_RNA_BSU13620
# Skipping DM_RNA_BSU13590
# Skipping DM_RNA_BSU18800
# Skipping DM_RNA_BSU19360
# Skipping DM_RNA_BSU19370
# Skipping DM_RNA_BSU26590
# Skipping DM_RNA_BSU26600
# Skipping DM_RNA_BSU35760
# Skipping DM_RNA_BSU35750
# Skipping DM_RNA_BSU13450
# Skipping DM_RNA_BSU15820
# Skipping DM_RNA_BSU28640
# Skipping DM_RNA_BSU38700
# Skipping DM_RNA_BSU27610
# Skipping DM_RNA_BSU_tRNA_76
# Skipping DM_RNA_BSU_tRNA_74
# Skipping DM_RNA_BSU_tRNA_78
# Skipping DM_RNA_BSU_tRNA_75
# Skipping DM_RNA_BSU_tRNA_77
# Skipping DM_RNA_BSU22090
# Skipping DM_RNA_BSU22110
# Skipping DM_RNA_BSU22100
# Skipping DM_RNA_BSU40550
# Skipping DM_RNA_BSU36510
# Skipping DM_RNA_BSU25290
# Skipping DM_RNA_BSU25300
# Skipping DM_RNA_BSU33240
# Skipping DM_RNA_BSU06310
# Skipping DM_RNA_BSU36760
# Skipping DM_RNA_BSU22490
# Skipping DM_RNA_BSU22440
# Skipping DM_RNA_BSU22480
# Skipping DM_RNA_BSU37150
# Skipping DM_RNA_BSU23770
# Skipping DM_RNA_BSU23760
# Skipping DM_RNA_BSU38830
# Skipping DM_RNA_BSU08850
# Skipping DM_RNA_BSU08830
# Skipping DM_RNA_BSU08860
# Skipping DM_RNA_BSU08840
# Skipping DM_RNA_BSU28750
# Skipping DM_RNA_BSU28740
# Skipping DM_RNA_BSU28790
# Skipping DM_RNA_BSU28720
# Skipping DM_RNA_BSU28780
# Skipping DM_RNA_BSU28800
# Skipping DM_RNA_BSU28730
# Skipping DM_RNA_BSU03070
# Skipping DM_RNA_BSU29060
# Skipping DM_RNA_BSU37660
# Skipping DM_RNA_BSU24740
# Skipping DM_RNA_BSU33040
# Skipping DM_RNA_BSU18120
# Skipping DM_RNA_BSU03860
# Skipping DM_RNA_BSU25580
# Skipping DM_RNA_BSU34130
# Skipping DM_RNA_BSU39920
# Skipping DM_RNA_BSU_tRNA_11
# Skipping DM_RNA_BSU29680
# Skipping DM_RNA_BSU27010
# Skipping DM_RNA_BSU27060
# Skipping DM_RNA_BSU27040
# Skipping DM_RNA_BSU27070
# Skipping DM_RNA_BSU27050
# Skipping DM_RNA_BSU19800
# Skipping DM_RNA_BSU17380
# Skipping DM_RNA_BSU17390
# Skipping DM_RNA_BSU30200
# Skipping DM_RNA_BSU30240
# Skipping DM_RNA_BSU30210
# Skipping DM_RNA_BSU30230
# Skipping DM_RNA_BSU30220
# Skipping DM_RNA_BSU21910
# Skipping DM_RNA_BSU27870
# Skipping DM_RNA_BSU27860
# Skipping DM_RNA_BSU27850
# Skipping DM_RNA_BSU28090
# Skipping DM_RNA_BSU28080
# Skipping DM_RNA_BSU14730
# Skipping DM_RNA_BSU02140
# Skipping DM_RNA_BSU02130
# Skipping DM_RNA_BSU28500
# Skipping DM_RNA_BSU09410
# Skipping DM_RNA_BSU38750
# Skipping DM_RNA_BSU38760
# Skipping DM_RNA_BSU33630
# Skipping DM_RNA_BSU15620
# Skipping DM_RNA_BSU15590
# Skipping DM_RNA_BSU15600
# Skipping DM_RNA_BSU15580
# Skipping DM_RNA_BSU15630
# Skipping DM_RNA_BSU15610
# Skipping DM_RNA_BSU15570
# Skipping DM_RNA_BSU28440
# Skipping DM_RNA_BSU28430
# Skipping DM_RNA_BSU28450
# Skipping DM_RNA_BSU02480
# Skipping DM_RNA_BSU02490
# Skipping DM_RNA_BSU02460
# Skipping DM_RNA_BSU02510
# Skipping DM_RNA_BSU10010
# Skipping DM_RNA_BSU_rRNA_6
# Skipping DM_RNA_BSU_tRNA_13
# Skipping DM_RNA_BSU_tRNA_18
# Skipping DM_RNA_BSU_tRNA_12
# Skipping DM_RNA_BSU_tRNA_17
# Skipping DM_RNA_BSU_tRNA_15
# Skipping DM_RNA_BSU_rRNA_8
# Skipping DM_RNA_BSU_tRNA_20
# Skipping DM_RNA_BSU_tRNA_19
# Skipping DM_RNA_BSU_tRNA_16
# Skipping DM_RNA_BSU_rRNA_7
# Skipping DM_RNA_BSU_tRNA_14
# Skipping DM_RNA_BSU16770
# Skipping DM_RNA_BSU16760
# Skipping DM_RNA_BSU16750
# Skipping DM_RNA_BSU16730
# Skipping DM_RNA_BSU16740
# Skipping DM_RNA_BSU28510
# Skipping DM_RNA_BSU36920
# Skipping DM_RNA_BSU03060
# Skipping DM_RNA_BSU03050
# Skipping DM_RNA_BSU07610
# Skipping DM_RNA_BSU29200
# Skipping DM_RNA_BSU29210
# Skipping DM_RNA_BSU39060
# Skipping DM_RNA_BSU28900
# Skipping DM_RNA_BSU24130
# Skipping DM_RNA_BSU24150
# Skipping DM_RNA_BSU24170
# Skipping DM_RNA_BSU24140
# Skipping DM_RNA_BSU24160
# Skipping DM_RNA_BSU24120
# Skipping DM_RNA_BSU10790
# Skipping DM_RNA_BSU04740
# Skipping DM_RNA_BSU04730
# Skipping DM_RNA_BSU39260
# Skipping DM_RNA_BSU39270
# Skipping DM_RNA_BSU08000
# Skipping DM_RNA_BSU_tRNA_6
# Skipping DM_RNA_BSU_tRNA_5
# Skipping DM_RNA_BSU_rRNA_1
# Skipping DM_RNA_BSU_rRNA_2
# Skipping DM_RNA_BSU_rRNA_3
# Skipping DM_RNA_BSU38500
# Skipping DM_RNA_BSU38510
# Skipping DM_RNA_BSU38530
# Skipping DM_RNA_BSU38520
# Skipping DM_RNA_BSU07840
# Skipping DM_RNA_BSU29670
# Skipping DM_RNA_BSU00410
# Skipping DM_RNA_BSU40190
# Skipping DM_RNA_BSU34190
# Skipping DM_RNA_BSU29790
# Skipping DM_RNA_BSU00820
# Skipping DM_RNA_BSU00740
# Skipping DM_RNA_BSU00750
# Skipping DM_RNA_BSU00790
# Skipping DM_RNA_BSU00770
# Skipping DM_RNA_BSU00810
# Skipping DM_RNA_BSU00780
# Skipping DM_RNA_BSU00760
# Skipping DM_RNA_BSU35290
# Skipping DM_RNA_BSU35300
# Skipping DM_RNA_BSU05740
# Skipping DM_RNA_BSU14590
# Skipping DM_RNA_BSU14600
# Skipping DM_RNA_BSU14610
# Skipping DM_RNA_BSU14580
# Skipping DM_RNA_BSU28910
# Skipping DM_RNA_BSU18470
# Skipping DM_RNA_BSU15500
# Skipping DM_RNA_BSU15510
# Skipping DM_RNA_BSU15520
# Skipping DM_RNA_BSU15540
# Skipping DM_RNA_BSU15490
# Skipping DM_RNA_BSU15530
# Skipping DM_RNA_BSU15550
# Skipping DM_RNA_BSU15480
# Skipping DM_RNA_BSU15560
# Skipping DM_RNA_BSU02390
# Skipping DM_RNA_BSU15980
# Skipping DM_RNA_BSU02420
# Skipping DM_RNA_BSU02430
# Skipping DM_RNA_BSU31322
# Skipping DM_RNA_BSU32000
# Skipping DM_RNA_BSU31980
# Skipping DM_RNA_BSU31970
# Skipping DM_RNA_BSU31990
# Skipping DM_RNA_BSU38860
# Skipping DM_RNA_BSU07990
# Skipping DM_RNA_BSU07810
# Skipping DM_RNA_BSU07800
# Skipping DM_RNA_BSU03130
# Skipping DM_RNA_BSU35590
# Skipping DM_RNA_BSU35580
# Skipping DM_RNA_BSU35570
# Skipping DM_RNA_BSU35609
# Skipping DM_RNA_BSU35540
# Skipping DM_RNA_BSU35600
# Skipping DM_RNA_BSU35550
# Skipping DM_RNA_BSU32410
# Skipping DM_RNA_BSU33960
# Skipping DM_RNA_BSU19350
# Skipping DM_RNA_BSU39610
# Skipping DM_RNA_BSU26970
# Skipping DM_RNA_BSU00730
# Skipping DM_RNA_BSU21870
# Skipping DM_RNA_BSU30320
# Skipping DM_RNA_BSU27810
# Skipping DM_RNA_BSU14920
# Skipping DM_RNA_BSU14910
# Skipping DM_RNA_BSU14890
# Skipping DM_RNA_BSU14880
# Skipping DM_RNA_BSU14900
# Skipping DM_RNA_BSU22780
# Skipping DM_RNA_BSU06470
# Skipping DM_RNA_BSU06510
# Skipping DM_RNA_BSU06520
# Skipping DM_RNA_BSU06420
# Skipping DM_RNA_BSU06430
# Skipping DM_RNA_BSU06490
# Skipping DM_RNA_BSU06450
# Skipping DM_RNA_BSU06480
# Skipping DM_RNA_BSU06440
# Skipping DM_RNA_BSU06500
# Skipping DM_RNA_BSU06530
# Skipping DM_RNA_BSU12290
# Skipping DM_RNA_BSU14530
# Skipping DM_RNA_BSU14540
# Skipping DM_RNA_BSU13580
# Skipping DM_RNA_BSU28470
# Skipping DM_RNA_BSU31660
# Skipping DM_RNA_BSU31640
# Skipping DM_RNA_BSU31620
# Skipping DM_RNA_BSU31610
# Skipping DM_RNA_BSU31630
# Skipping DM_RNA_BSU31650
# Skipping DM_RNA_BSU04520
# Skipping DM_RNA_BSU35790
# Skipping DM_RNA_BSU14870
# Skipping DM_RNA_BSU37760
# Skipping DM_RNA_BSU37780
# Skipping DM_RNA_BSU03910
# Skipping DM_RNA_BSU03900
# Skipping DM_RNA_BSU24980
# Skipping DM_RNA_BSU24960
# Skipping DM_RNA_BSU24950
# Skipping DM_RNA_BSU24970
# Skipping DM_RNA_BSU24990
# Skipping DM_RNA_BSU18450
# Skipping DM_RNA_BSU18440
# Skipping DM_RNA_BSU00120
# Skipping DM_RNA_BSU00110
# Skipping DM_RNA_BSU39980
# Skipping DM_RNA_BSU29750
# Skipping DM_RNA_BSU25710
# Skipping DM_RNA_BSU21680
# Skipping DM_RNA_BSU30300
# Skipping DM_RNA_BSU27120
# Skipping DM_RNA_BSU00980
# Skipping DM_RNA_BSU35920
# Skipping DM_RNA_BSU35960
# Skipping DM_RNA_BSU35940
# Skipping DM_RNA_BSU35950
# Skipping DM_RNA_BSU35930
# Skipping DM_RNA_BSU06020
# Skipping DM_RNA_BSU06030
# Skipping DM_RNA_BSU30780
# Skipping DM_RNA_BSU30800
# Skipping DM_RNA_BSU30830
# Skipping DM_RNA_BSU30790
# Skipping DM_RNA_BSU30820
# Skipping DM_RNA_BSU38020
# Skipping DM_RNA_BSU06370
# Skipping DM_RNA_BSU22650
# Skipping DM_RNA_BSU22600
# Skipping DM_RNA_BSU22640
# Skipping DM_RNA_BSU22660
# Skipping DM_RNA_BSU22670
# Skipping DM_RNA_BSU22620
# Skipping DM_RNA_BSU22680
# Skipping DM_RNA_BSU22610
# Skipping DM_RNA_BSU22630
# Skipping DM_RNA_BSU13300
# Skipping DM_RNA_BSU01050
# Skipping DM_RNA_BSU01040
# Skipping DM_RNA_BSU28270
# Skipping DM_RNA_BSU28260
# Skipping DM_RNA_BSU28300
# Skipping DM_RNA_BSU28280
# Skipping DM_RNA_BSU28310
# Skipping DM_RNA_BSU28250
# Skipping DM_RNA_BSU28290
# Skipping DM_RNA_BSU31580
# Skipping DM_RNA_BSU19230
# Skipping DM_RNA_BSU27250
# Skipping DM_RNA_BSU27270
# Skipping DM_RNA_BSU27260
# Skipping DM_RNA_BSU40910
# Skipping DM_RNA_BSU40890
# Skipping DM_RNA_BSU_tRNA_73
# Skipping DM_RNA_BSU37330
# Skipping DM_RNA_BSU03270
# Skipping DM_RNA_BSU00090
# Skipping DM_RNA_BSU36590
# Skipping DM_RNA_BSU29220
# Skipping DM_RNA_BSU38170
# Skipping DM_RNA_BSU38150
# Skipping DM_RNA_BSU38160
# Skipping DM_RNA_BSU38140
# Skipping DM_RNA_BSU29600
# Skipping DM_RNA_BSU13010
# Skipping DM_RNA_BSU40040
# Skipping DM_RNA_BSU38490
# Skipping DM_RNA_BSU00930
# Skipping DM_RNA_BSU00940
# Skipping DM_RNA_BSU08650
# Skipping DM_RNA_BSU30430
# Skipping DM_RNA_BSU30420
# Skipping DM_RNA_BSU30410
# Skipping DM_RNA_BSU30450
# Skipping DM_RNA_BSU30440
# Skipping DM_RNA_BSU27900
# Skipping DM_RNA_BSU27910
# Skipping DM_RNA_BSU14860
# Skipping DM_RNA_BSU22560
# Skipping DM_RNA_BSU22550
# Skipping DM_RNA_BSU22540
# Skipping DM_RNA_BSU25260
# Skipping DM_RNA_BSU25270
# Skipping DM_RNA_BSU06160
# Skipping DM_RNA_BSU06150
# Skipping DM_RNA_BSU31180
# Skipping DM_RNA_BSU31200
# Skipping DM_RNA_BSU28230
# Skipping DM_RNA_BSU09540
# Skipping DM_RNA_BSU09530
# Skipping DM_RNA_BSU02360
# Skipping DM_RNA_BSU02350
# Skipping DM_RNA_BSU23800
# Skipping DM_RNA_BSU34200
# Skipping DM_RNA_BSU37320
# Skipping DM_RNA_BSU37710
# Skipping DM_RNA_BSU11240
# Skipping DM_RNA_BSU11220
# Skipping DM_RNA_BSU11210
# Skipping DM_RNA_BSU11200
# Skipping DM_RNA_BSU11230
# Skipping DM_RNA_BSU11190
# Skipping DM_RNA_BSU11250
# Skipping DM_RNA_BSU11880
# Skipping DM_RNA_BSU11870
# Skipping DM_RNA_BSU33500
# Skipping DM_RNA_BSU33510
# Skipping DM_RNA_BSU39780
# Skipping DM_RNA_BSU12920
# Skipping DM_RNA_BSU12940
# Skipping DM_RNA_BSU12930
# Skipping DM_RNA_BSU12960
# Skipping DM_RNA_BSU12950
# Skipping DM_RNA_BSU18410
# Skipping DM_RNA_BSU04360
# Skipping DM_RNA_BSU00900
# Skipping DM_RNA_BSU00910
# Skipping DM_RNA_BSU21770
# Skipping DM_RNA_BSU03220
# Skipping DM_RNA_BSU32200
# Skipping DM_RNA_BSU36000
# Skipping DM_RNA_BSU36010
# Skipping DM_RNA_BSU32260
# Skipping DM_RNA_BSU32250
# Skipping DM_RNA_BSU32240
# Skipping DM_RNA_BSU16090
# Skipping DM_RNA_BSU16100
# Skipping DM_RNA_BSU23070
# Skipping DM_RNA_BSU28560
# Skipping DM_RNA_BSU28540
# Skipping DM_RNA_BSU02860
# Skipping DM_RNA_BSU02850
# Skipping DM_RNA_BSU02870
# Skipping DM_RNA_BSU17410
# Skipping DM_RNA_BSU11010
# Skipping DM_RNA_BSU03150
# Skipping DM_RNA_BSU25550
# Skipping DM_RNA_BSU15650
# Skipping DM_RNA_BSU37110
# Skipping DM_RNA_BSU37120
# Skipping DM_RNA_BSU23850
# Skipping DM_RNA_BSU32470
# Skipping DM_RNA_BSU32500
# Skipping DM_RNA_BSU32510
# Skipping DM_RNA_BSU32490
# Skipping DM_RNA_BSU32480
# Skipping DM_RNA_BSU_tRNA_7
# Skipping DM_RNA_BSU_misc_RNA_2
# Skipping DM_RNA_BSU_rRNA_4
# Skipping DM_RNA_BSU_tRNA_8
# Skipping DM_RNA_BSU_tRNA_9
# Skipping DM_RNA_BSU_rRNA_5
# Skipping DM_RNA_BSU_rRNA_26
# Skipping DM_RNA_BSU00270
# Skipping DM_RNA_BSU00280
# Skipping DM_RNA_BSU00460
# Skipping DM_RNA_BSU00550
# Skipping DM_RNA_BSU_tRNA_10
# Skipping DM_RNA_BSU00680
# Skipping DM_RNA_BSU_rRNA_9
# Skipping DM_RNA_BSU_rRNA_10
# Skipping DM_RNA_BSU_rRNA_11
# Skipping DM_RNA_BSU00990
# Skipping DM_RNA_BSU01000
# Skipping DM_RNA_BSU01010
# Skipping DM_RNA_BSU01020
# Skipping DM_RNA_BSU01030
# Skipping DM_RNA_BSU01080
# Skipping DM_RNA_BSU01100
# Skipping DM_RNA_BSU01110
# Skipping DM_RNA_BSU01120
# Skipping DM_RNA_BSU01130
# Skipping DM_RNA_BSU01150
# Skipping DM_RNA_BSU01160
# Skipping DM_RNA_BSU01170
# Skipping DM_RNA_BSU01180
# Skipping DM_RNA_BSU01190
# Skipping DM_RNA_BSU01200
# Skipping DM_RNA_BSU01210
# Skipping DM_RNA_BSU01220
# Skipping DM_RNA_BSU01230
# Skipping DM_RNA_BSU01240
# Skipping DM_RNA_BSU01250
# Skipping DM_RNA_BSU01260
# Skipping DM_RNA_BSU01270
# Skipping DM_RNA_BSU01280
# Skipping DM_RNA_BSU01290
# Skipping DM_RNA_BSU01300
# Skipping DM_RNA_BSU01310
# Skipping DM_RNA_BSU01320
# Skipping DM_RNA_BSU01330
# Skipping DM_RNA_BSU01340
# Skipping DM_RNA_BSU01350
# Skipping DM_RNA_BSU01360
# Skipping DM_RNA_BSU01370
# Skipping DM_RNA_BSU01380
# Skipping DM_RNA_BSU01390
# Skipping DM_RNA_BSU01400
# Skipping DM_RNA_BSU01410
# Skipping DM_RNA_BSU01420
# Skipping DM_RNA_BSU01430
# Skipping DM_RNA_BSU01440
# Skipping DM_RNA_BSU01490
# Skipping DM_RNA_BSU01500
# Skipping DM_RNA_BSU_rRNA_23
# Skipping DM_RNA_BSU_rRNA_14
# Skipping DM_RNA_BSU_rRNA_15
# Skipping DM_RNA_BSU_tRNA_23
# Skipping DM_RNA_BSU_tRNA_24
# Skipping DM_RNA_BSU_tRNA_25
# Skipping DM_RNA_BSU_tRNA_26
# Skipping DM_RNA_BSU_tRNA_27
# Skipping DM_RNA_BSU_tRNA_28
# Skipping DM_RNA_BSU_rRNA_16
# Skipping DM_RNA_BSU_rRNA_29
# Skipping DM_RNA_BSU_rRNA_24
# Skipping DM_RNA_BSU_rRNA_25
# Skipping DM_RNA_BSU_rRNA_27
# Skipping DM_RNA_BSU_rRNA_28
# Skipping DM_RNA_BSU01580
# Skipping DM_RNA_BSU01680
# Skipping DM_RNA_BSU02340
# Skipping DM_RNA_BSU02400
# Skipping DM_RNA_BSU02630
# Skipping DM_RNA_BSU02640
# Skipping DM_RNA_BSU03950
# Skipping DM_RNA_BSU04560
# Skipping DM_RNA_BSU04570
# Skipping DM_RNA_BSU04620
# Skipping DM_RNA_BSU04640
# Skipping DM_RNA_BSU_tRNA_45
# Skipping DM_RNA_BSU_tRNA_46
# Skipping DM_RNA_BSU_tRNA_47
# Skipping DM_RNA_BSU_tRNA_48
# Skipping DM_RNA_BSU_tRNA_49
# Skipping DM_RNA_BSU_tRNA_50
# Skipping DM_RNA_BSU_tRNA_51
# Skipping DM_RNA_BSU05340
# Skipping DM_RNA_BSU_tRNA_79
# Skipping DM_RNA_BSU_tRNA_80
# Skipping DM_RNA_BSU_rRNA_30
# Skipping DM_RNA_BSU_rRNA_12
# Skipping DM_RNA_BSU_rRNA_13
# Skipping DM_RNA_BSU_tRNA_21
# Skipping DM_RNA_BSU_tRNA_22
# Skipping DM_RNA_BSU05900
# Skipping DM_RNA_BSU05980
# Skipping DM_RNA_BSU05990
# Skipping DM_RNA_BSU06170
# Skipping DM_RNA_BSU06670
# Skipping DM_RNA_BSU06680
# Skipping DM_RNA_BSU06690
# Skipping DM_RNA_BSU06730
# Skipping DM_RNA_BSU06970
# Skipping DM_RNA_BSU06980
# Skipping DM_RNA_BSU06990
# Skipping DM_RNA_BSU08710
# Skipping DM_RNA_BSU_rRNA_22
# Skipping DM_RNA_BSU_rRNA_17
# Skipping DM_RNA_BSU_rRNA_18
# Skipping DM_RNA_BSU_tRNA_29
# Skipping DM_RNA_BSU_tRNA_30
# Skipping DM_RNA_BSU_tRNA_31
# Skipping DM_RNA_BSU_tRNA_32
# Skipping DM_RNA_BSU_tRNA_33
# Skipping DM_RNA_BSU_tRNA_34
# Skipping DM_RNA_BSU_tRNA_35
# Skipping DM_RNA_BSU_tRNA_36
# Skipping DM_RNA_BSU_tRNA_37
# Skipping DM_RNA_BSU_tRNA_38
# Skipping DM_RNA_BSU_tRNA_39
# Skipping DM_RNA_BSU_tRNA_40
# Skipping DM_RNA_BSU_tRNA_41
# Skipping DM_RNA_BSU_tRNA_42
# Skipping DM_RNA_BSU_tRNA_43
# Skipping DM_RNA_BSU_tRNA_44
# Skipping DM_RNA_BSU08790
# Skipping DM_RNA_BSU_tRNA_82
# Skipping DM_RNA_BSU09240
# Skipping DM_RNA_BSU09310
# Skipping DM_RNA_BSU09680
# Skipping DM_RNA_BSU09850
# Skipping DM_RNA_BSU10020
# Skipping DM_RNA_BSU10220
# Skipping DM_RNA_BSU10360
# Skipping DM_RNA_BSU10870
# Skipping DM_RNA_BSU11610
# Skipping DM_RNA_BSU11640
# Skipping DM_RNA_BSU_tRNA_83
# Skipping DM_RNA_BSU12080
# Skipping DM_RNA_BSU12160
# Skipping DM_RNA_BSU13110
# Skipping DM_RNA_BSU13180
# Skipping DM_RNA_BSU13730
# Skipping DM_RNA_BSU13960
# Skipping DM_RNA_BSU14000
# Skipping DM_RNA_BSU14180
# Skipping DM_RNA_BSU14190
# Skipping DM_RNA_BSU14520
# Skipping DM_RNA_BSU14670
# Skipping DM_RNA_BSU14830
# Skipping DM_RNA_BSU15020
# Skipping DM_RNA_BSU15080
# Skipping DM_RNA_BSU15350
# Skipping DM_RNA_BSU15430
# Skipping DM_RNA_BSU15680
# Skipping DM_RNA_BSU15690
# Skipping DM_RNA_BSU15700
# Skipping DM_RNA_BSU15720
# Skipping DM_RNA_BSU15730
# Skipping DM_RNA_BSU15750
# Skipping DM_RNA_BSU15790
# Skipping DM_RNA_BSU15850
# Skipping DM_RNA_BSU15860
# Skipping DM_RNA_BSU15920
# Skipping DM_RNA_BSU16020
# Skipping DM_RNA_BSU16040
# Skipping DM_RNA_BSU16490
# Skipping DM_RNA_BSU16500
# Skipping DM_RNA_BSU16510
# Skipping DM_RNA_BSU16520
# Skipping DM_RNA_BSU16530
# Skipping DM_RNA_BSU16540
# Skipping DM_RNA_BSU16550
# Skipping DM_RNA_BSU16570
# Skipping DM_RNA_BSU16670
# Skipping DM_RNA_BSU16680
# Skipping DM_RNA_BSU16690
# Skipping DM_RNA_BSU16960
# Skipping DM_RNA_BSU16990
# Skipping DM_RNA_BSU17000
# Skipping DM_RNA_BSU17660
# Skipping DM_RNA_BSU17710
# Skipping DM_RNA_BSU_tRNA_85
# Skipping DM_RNA_BSU18480
# Skipping DM_RNA_BSU18540
# Skipping DM_RNA_BSU18570
# Skipping DM_RNA_BSU18830
# Skipping DM_RNA_BSU19310
# Skipping DM_RNA_BSU19520
# Skipping DM_RNA_BSU19630
# Skipping DM_RNA_BSU19690
# Skipping DM_RNA_BSU19710
# Skipping DM_RNA_BSU20020
# Skipping DM_RNA_BSU20250
# Skipping DM_RNA_BSU21690
# Skipping DM_RNA_BSU21810
# Skipping DM_RNA_BSU21820
# Skipping DM_RNA_BSU21900
# Skipping DM_RNA_BSU21920
# Skipping DM_RNA_BSU22130
# Skipping DM_RNA_BSU22140
# Skipping DM_RNA_BSU22360
# Skipping DM_RNA_BSU22370
# Skipping DM_RNA_BSU22410
# Skipping DM_RNA_BSU22420
# Skipping DM_RNA_BSU22430
# Skipping DM_RNA_BSU22690
# Skipping DM_RNA_BSU22700
# Skipping DM_RNA_BSU22710
# Skipping DM_RNA_BSU22730
# Skipping DM_RNA_BSU22740
# Skipping DM_RNA_BSU22750
# Skipping DM_RNA_BSU22760
# Skipping DM_RNA_BSU22830
# Skipping DM_RNA_BSU22870
# Skipping DM_RNA_BSU22880
# Skipping DM_RNA_BSU22890
# Skipping DM_RNA_BSU23380
# Skipping DM_RNA_BSU23560
# Skipping DM_RNA_BSU23610
# Skipping DM_RNA_BSU23920
# Skipping DM_RNA_BSU23960
# Skipping DM_RNA_BSU23970
# Skipping DM_RNA_BSU23980
# Skipping DM_RNA_BSU24270
# Skipping DM_RNA_BSU24280
# Skipping DM_RNA_BSU24850
# Skipping DM_RNA_BSU24900
# Skipping DM_RNA_BSU25020
# Skipping DM_RNA_BSU25160
# Skipping DM_RNA_BSU25310
# Skipping DM_RNA_BSU25410
# Skipping DM_RNA_BSU25640
# Skipping DM_RNA_BSU25660
# Skipping DM_RNA_BSU25900
# Skipping DM_RNA_BSU26640
# Skipping DM_RNA_BSU26650
# Skipping DM_RNA_BSU26810
# Skipping DM_RNA_BSU26860
# Skipping DM_RNA_BSU27200
# Skipping DM_RNA_BSU27220
# Skipping DM_RNA_BSU27320
# Skipping DM_RNA_BSU27330
# Skipping DM_RNA_BSU27410
# Skipping DM_RNA_BSU27550
# Skipping DM_RNA_BSU27560
# Skipping DM_RNA_BSU27650
# Skipping DM_RNA_BSU27960
# Skipping DM_RNA_BSU_tRNA_84
# Skipping DM_RNA_BSU28370
# Skipping DM_RNA_BSU28390
# Skipping DM_RNA_BSU28680
# Skipping DM_RNA_BSU29050
# Skipping DM_RNA_BSU29440
# Skipping DM_RNA_BSU29450
# Skipping DM_RNA_BSU30690
# Skipping DM_RNA_BSU30870
# Skipping DM_RNA_BSU31050
# Skipping DM_RNA_BSU31060
# Skipping DM_RNA_BSU31090
# Skipping DM_RNA_BSU31100
# Skipping DM_RNA_BSU_tRNA_86
# Skipping DM_RNA_BSU31150
# Skipping DM_RNA_BSU31400
# Skipping DM_RNA_BSU31600
# Skipping DM_RNA_BSU31760
# Skipping DM_RNA_BSU32100
# Skipping DM_RNA_BSU32170
# Skipping DM_RNA_BSU32180
# Skipping DM_RNA_BSU32680
# Skipping DM_RNA_BSU33160
# Skipping DM_RNA_BSU33170
# Skipping DM_RNA_BSU33180
# Skipping DM_RNA_BSU33290
# Skipping DM_RNA_BSU33300
# Skipping DM_RNA_BSU33310
# Skipping DM_RNA_BSU33330
# Skipping DM_RNA_BSU33380
# Skipping DM_RNA_BSU33390
# Skipping DM_RNA_BSU33420
# Skipping DM_RNA_BSU33490
# Skipping DM_RNA_BSU_tRNA_81
# Skipping DM_RNA_BSU34550
# Skipping DM_RNA_BSU34560
# Skipping DM_RNA_BSU34570
# Skipping DM_RNA_BSU34590
# Skipping DM_RNA_BSU34600
# Skipping DM_RNA_BSU34610
# Skipping DM_RNA_BSU34660
# Skipping DM_RNA_BSU34790
# Skipping DM_RNA_BSU34860
# Skipping DM_RNA_BSU34870
# Skipping DM_RNA_BSU34880
# Skipping DM_RNA_BSU34890
# Skipping DM_RNA_BSU34900
# Skipping DM_RNA_BSU34910
# Skipping DM_RNA_BSU34920
# Skipping DM_RNA_BSU35530
# Skipping DM_RNA_BSU35680
# Skipping DM_RNA_BSU35690
# Skipping DM_RNA_BSU35700
# Skipping DM_RNA_BSU35710
# Skipping DM_RNA_BSU36030
# Skipping DM_RNA_BSU36120
# Skipping DM_RNA_BSU36130
# Skipping DM_RNA_BSU36370
# Skipping DM_RNA_BSU36710
# Skipping DM_RNA_BSU37010
# Skipping DM_RNA_BSU37060
# Skipping DM_RNA_BSU37080
# Skipping DM_RNA_BSU37100
# Skipping DM_RNA_BSU37190
# Skipping DM_RNA_BSU37240
# Skipping DM_RNA_BSU38240
# Skipping DM_RNA_BSU38390
# Skipping DM_RNA_BSU_tRNA_1
# Skipping DM_RNA_BSU_tRNA_2
# Skipping DM_RNA_BSU_tRNA_3
# Skipping DM_RNA_BSU_tRNA_4
# Skipping DM_RNA_BSU40850
# Skipping DM_RNA_BSU41050
# Skipping DM_RNA_dummy

# %%
df = pd.DataFrame.from_dict(comparison_dict).T

# %%
np.log10(df[df.abs()>0]).plot(x='m',y='me',style='o',figsize=(6.5,5))
plt.plot([-6,2],[-6,2],'--k')

plt.xlim([-6.5,6.5])
plt.ylabel('ME-predictions')
plt.xlabel('Mm-predictions')
plt.savefig('analysis/figures/me_m_flux_XY.svg',format='SVG')
# Out:
# /home/jt/UCSD/ME_modelling/ME_env/lib/python3.6/site-packages/ipykernel_launcher.py:1 RuntimeWarning: invalid value encountered in log10

# %%
fig = plt.figure(figsize=(6.5,5))
np.log10(df[df.abs()>0])['m'].hist(bins=50,alpha=0.5,label='m')
np.log10(df[df.abs()>0])['me'].hist(bins=40,alpha=0.5,label='me')

plt.xlabel('log10(flux)')
plt.ylabel('Count')
plt.legend()
plt.savefig('analysis/figures/me_m_flux_distributions.svg',format='SVG')
# Out:
# /home/jt/UCSD/ME_modelling/ME_env/lib/python3.6/site-packages/ipykernel_launcher.py:2 RuntimeWarning: invalid value encountered in log10
# /home/jt/UCSD/ME_modelling/ME_env/lib/python3.6/site-packages/ipykernel_launcher.py:3 RuntimeWarning: invalid value encountered in log10

# %%
get_reactions_of_met(me,'fol_c',only_types=['MetabolicReaction'])
# Out:
# []

# %%
me.reactions.translation_BSU00090.reaction
# Out:
# '10fthf_c + 0.00208119658119658*mu BSU01120-MONOMER + 4.27350427350427e-6*mu BSU01390-MONOMER + 4.27350427350427e-6*mu BSU15720-MONOMER + 4.27350427350427e-6*mu BSU15730-MONOMER + 0.00208119658119658*mu BSU16500-MONOMER + 4.27350427350427e-6*mu BSU16520-MONOMER + 8.54700854700855e-6*mu BSU16630-MONOMER + 4.27350427350427e-6*mu BSU28870-MONOMER + 4.27350427350427e-6*mu BSU35290-MONOMER + 0.000498399634202103*mu + 0.000195123456790123 + 0.00598079561042524*(mu + 0.3915)/mu RNA_BSU00090 + 2.55589556001079e-8*mu + 1.00063311174422e-8 RNA_degradosome + 36 ala__L_c + 23 arg__L_c + 14 asn__L_c + 27 asp__L_c + 487.0 + 2.19196159122085*(mu + 0.3915)/mu atp_c + 3 cys__L_c + 4.27350427350427e-6*mu generic_RF + 0.00208119658119658*mu generic_Tuf + 29.0 generic_tRNA_AAA_lys__L_c + 8.0 generic_tRNA_AAC_asn__L_c + 8.0 generic_tRNA_AAG_lys__L_c + 6.0 generic_tRNA_AAU_asn__L_c + 18.0 generic_tRNA_ACA_thr__L_c + generic_tRNA_ACC_thr__L_c + 4.0 generic_tRNA_ACG_thr__L_c + 12.0 generic_tRNA_ACU_thr__L_c + 7.0 generic_tRNA_AGA_arg__L_c + 5.0 generic_tRNA_AGC_ser__L_c + 2.0 generic_tRNA_AGU_ser__L_c + generic_tRNA_AUA_ile__L_c + 13.0 generic_tRNA_AUC_ile__L_c + 13.0 generic_tRNA_AUG_met__L_c + 26.0 generic_tRNA_AUU_ile__L_c + 6.0 generic_tRNA_CAA_gln__L_c + 6.0 generic_tRNA_CAC_his__L_c + 9.0 generic_tRNA_CAG_gln__L_c + 5.0 generic_tRNA_CAU_his__L_c + 2.0 generic_tRNA_CCA_pro__L_c + 2.0 generic_tRNA_CCC_pro__L_c + 5.0 generic_tRNA_CCG_pro__L_c + 8.0 generic_tRNA_CCU_pro__L_c + 7.0 generic_tRNA_CGC_arg__L_c + 9.0 generic_tRNA_CGU_arg__L_c + 4.0 generic_tRNA_CUA_leu__L_c + 2.0 generic_tRNA_CUC_leu__L_c + 4.0 generic_tRNA_CUG_leu__L_c + 12.0 generic_tRNA_CUU_leu__L_c + 33.0 generic_tRNA_GAA_glu__L_c + 13.0 generic_tRNA_GAC_asp__L_c + 5.0 generic_tRNA_GAG_glu__L_c + 14.0 generic_tRNA_GAU_asp__L_c + 17.0 generic_tRNA_GCA_ala__L_c + 4.0 generic_tRNA_GCC_ala__L_c + 6.0 generic_tRNA_GCG_ala__L_c + 9.0 generic_tRNA_GCU_ala__L_c + 14.0 generic_tRNA_GGA_gly_c + 18.0 generic_tRNA_GGC_gly_c + 6.0 generic_tRNA_GGG_gly_c + 9.0 generic_tRNA_GGU_gly_c + 13.0 generic_tRNA_GUA_val__L_c + 7.0 generic_tRNA_GUC_val__L_c + 5.0 generic_tRNA_GUG_val__L_c + 20.0 generic_tRNA_GUU_val__L_c + generic_tRNA_START_met__L_c + 6.0 generic_tRNA_UAC_tyr__L_c + 5.0 generic_tRNA_UAU_tyr__L_c + 9.0 generic_tRNA_UCA_ser__L_c + 3.0 generic_tRNA_UCC_ser__L_c + 9.0 generic_tRNA_UCU_ser__L_c + generic_tRNA_UGC_cys__L_c + generic_tRNA_UGG_trp__L_c + 2.0 generic_tRNA_UGU_cys__L_c + 7.0 generic_tRNA_UUA_leu__L_c + 6.0 generic_tRNA_UUC_phe__L_c + 5.0 generic_tRNA_UUG_leu__L_c + 6.0 generic_tRNA_UUU_phe__L_c + 15 gln__L_c + 38 glu__L_c + 47 gly_c + 976.0 gtp_c + 977.0 + 2.19196159122085*(mu + 0.3915)/mu h2o_c + 11 his__L_c + 40 ile__L_c + 34 leu__L_c + 37 lys__L_c + 2.79315125094996*(mu + 0.3915)/mu mRNA_biomass + 14 met__L_c + 12 phe__L_c + 17 pro__L_c + 0.00699627131605108*mu + 0.002739040220234 ribosome + 28 ser__L_c + 35 thr__L_c + trp__L_c + 11 tyr__L_c + 45 val__L_c --> 2.19196159122085*(mu + 0.3915)/mu adp_c + 487.0 + 2.15308641975309*(mu + 0.3915)/mu amp_c + 2.06935528120713*(mu + 0.3915)/mu cmp_c + for_c + 976.0 gdp_c + 1.74639231824417*(mu + 0.3915)/mu gmp_c + 1463.0 + 2.19196159122085*(mu + 0.3915)/mu h_c + 976.0 + 2.19196159122085*(mu + 0.3915)/mu pi_c + 487.0 ppi_c + protein_BSU00090 + 52.98614028 protein_biomass + thf_c + 2.80499314128944*(mu + 0.3915)/mu ump_c'

# %%
me.reactions.transcription_TU_BSU_rRNA_10.reaction
# Out:
# '4.27350427350427e-6*mu BSU00550-MONOMER + 4.27350427350427e-6*mu BSU01010-MONOMER + 4.27350427350427e-6*mu BSU16600-MONOMER + 4.27350427350427e-6*mu BSU27320-MONOMER + 4.27350427350427e-6*mu CPLX8J2-30 + 571 atp_c + 920 ctp_c + 658 gtp_c + 779 utp_c --> RNA_BSU_rRNA_10 + 2928 ppi_c + 931.440514868 rRNA_biomass'

# %%
get_reactions_of_met(me,'generic_tRNA_UGU_cys__L_c',s=1)
# Out:
# ( charging_tRNA_BSU_tRNA_42_UGU 0.0 1000.0 ) 	 4.27350427350427e-6*mu*(0.000116266666666667*mu + 1.0000455184) BSU00940-MONOMER + 0.000116266666666667*mu + 4.55184e-5 RNA_BSU_tRNA_42 + 0.000116266666666667*mu + 4.55184e-5 cys__L_c --> generic_tRNA_UGU_cys__L_c
# [<tRNAChargingReaction charging_tRNA_BSU_tRNA_42_UGU at 0x7f86eda60208>]

# %%
ecome.reactions.charging_tRNA_b0202_AUC.reaction
# Out:
# ' --> 0.000116266666666667*mu + 4.55184e-5 5mta_c + -4.27350427350427e-6*mu*(0.000116266666666667*mu + 1.0000455184) IleS_mono_mod_2:zn2 + -0.000116266666666667*mu - 4.55184e-5 RNA_b0202 + -4.27350427350427e-6*mu*(0.000116266666666667*mu + 4.55184e-5) TrmA_mono + -4.27350427350427e-6*mu*(0.000116266666666667*mu + 4.55184e-5) TruB_mono + -4.27350427350427e-6*mu*(0.000116266666666667*mu + 4.55184e-5) YggH_mono + -4.27350427350427e-6*mu*(0.000116266666666667*mu + 4.55184e-5) YqcB_mono + -4.27350427350427e-6*mu*(0.000116266666666667*mu + 4.55184e-5) YrdC_mono + 0.000232533333333333*mu + 9.10368e-5 ahcys_c + -0.0003488*mu - 0.0001365552 amet_c + 0.000116266666666667*mu + 4.55184e-5 amp_c + -0.000116266666666667*mu - 4.55184e-5 atp_c + -8.54700854700855e-6*mu*(0.000116266666666667*mu + 4.55184e-5) generic_Dus + generic_tRNA_AUC_ile__L_c + 0.000116266666666667*mu + 4.55184e-5 h2o_c + 0.000232533333333333*mu + 9.10368e-5 h_c + -0.000116266666666667*mu - 4.55184e-5 hco3_c + -0.000116266666666667*mu - 4.55184e-5 ile__L_c + 0.000232533333333333*mu + 9.10368e-5 nadp_c + -0.000232533333333333*mu - 9.10368e-5 nadph_c + 0.000116266666666667*mu + 4.55184e-5 ppi_c + -0.000116266666666667*mu - 4.55184e-5 thr__L_c'

# %%
ecome.reactions.translation_b0002.reaction
# Out:
# '10fthf_c + 91 ala__L_c + 46 arg__L_c + 38 asn__L_c + 44 asp__L_c + 12 cys__L_c + 22.0 generic_tRNA_AAA_lys__L_c + 16.0 generic_tRNA_AAC_asn__L_c + 12.0 generic_tRNA_AAG_lys__L_c + 22.0 generic_tRNA_AAU_asn__L_c + 2.0 generic_tRNA_ACA_thr__L_c + 19.0 generic_tRNA_ACC_thr__L_c + 8.0 generic_tRNA_ACG_thr__L_c + 5.0 generic_tRNA_ACU_thr__L_c + 12.0 generic_tRNA_AGC_ser__L_c + 2.0 generic_tRNA_AGG_arg__L_c + 3.0 generic_tRNA_AGU_ser__L_c + generic_tRNA_AUA_ile__L_c + 15.0 generic_tRNA_AUC_ile__L_c + 22.0 generic_tRNA_AUG_met__L_c + 30.0 generic_tRNA_AUU_ile__L_c + 11.0 generic_tRNA_CAA_gln__L_c + 6.0 generic_tRNA_CAC_his__L_c + 19.0 generic_tRNA_CAG_gln__L_c + 8.0 generic_tRNA_CAU_his__L_c + 2.0 generic_tRNA_CCA_pro__L_c + 6.0 generic_tRNA_CCC_pro__L_c + 18.0 generic_tRNA_CCG_pro__L_c + 3.0 generic_tRNA_CCU_pro__L_c + 3.0 generic_tRNA_CGA_arg__L_c + 19.0 generic_tRNA_CGC_arg__L_c + 4.0 generic_tRNA_CGG_arg__L_c + 18.0 generic_tRNA_CGU_arg__L_c + 2.0 generic_tRNA_CUA_leu__L_c + 13.0 generic_tRNA_CUC_leu__L_c + 43.0 generic_tRNA_CUG_leu__L_c + 8.0 generic_tRNA_CUU_leu__L_c + 40.0 generic_tRNA_GAA_glu__L_c + 14.0 generic_tRNA_GAC_asp__L_c + 13.0 generic_tRNA_GAG_glu__L_c + 30.0 generic_tRNA_GAU_asp__L_c + 14.0 generic_tRNA_GCA_ala__L_c + 36.0 generic_tRNA_GCC_ala__L_c + 26.0 generic_tRNA_GCG_ala__L_c + 15.0 generic_tRNA_GCU_ala__L_c + 9.0 generic_tRNA_GGA_gly_c + 22.0 generic_tRNA_GGC_gly_c + 10.0 generic_tRNA_GGG_gly_c + 22.0 generic_tRNA_GGU_gly_c + 5.0 generic_tRNA_GUA_val__L_c + 18.0 generic_tRNA_GUC_val__L_c + 27.0 generic_tRNA_GUG_val__L_c + 19.0 generic_tRNA_GUU_val__L_c + generic_tRNA_START_met__L_c + 8.0 generic_tRNA_UAC_tyr__L_c + 12.0 generic_tRNA_UAU_tyr__L_c + 6.0 generic_tRNA_UCA_ser__L_c + 10.0 generic_tRNA_UCC_ser__L_c + 9.0 generic_tRNA_UCG_ser__L_c + 11.0 generic_tRNA_UCU_ser__L_c + 9.0 generic_tRNA_UGC_cys__L_c + 4.0 generic_tRNA_UGG_trp__L_c + 3.0 generic_tRNA_UGU_cys__L_c + 10.0 generic_tRNA_UUA_leu__L_c + 19.0 generic_tRNA_UUC_phe__L_c + 13.0 generic_tRNA_UUG_leu__L_c + 11.0 generic_tRNA_UUU_phe__L_c + 30 gln__L_c + 53 glu__L_c + 63 gly_c + 1640.0 gtp_c + 14 his__L_c + 46 ile__L_c + 89 leu__L_c + 34 lys__L_c + 23 met__L_c + 30 phe__L_c + 29 pro__L_c + 51 ser__L_c + 34 thr__L_c + 4 trp__L_c + 20 tyr__L_c + 69 val__L_c --> -2.72438972852433e-7*mu Def_mono_mod_1:fe2 + -1.80324164444648e-7*mu Fmt_mono_mod_mg2_mod_k + -0.0035*mu FusA_mono + -4.27350427350427e-6*mu InfA_mono + -4.45382843794892e-6*mu InfB_mono + -4.27350427350427e-6*mu InfC_mono + -1.63370183870619e-7*mu PrfB_mono + -4.27350427350427e-6*mu PrfC_mono + -0.000498399634202103*mu - 0.000195123456790123 - 0.00598079561042524*(mu + 0.3915)/mu RNA_b0002 + -2.55589556001079e-8*mu - 1.00063311174422e-8 RNA_degradosome + -2.62130898398882e-7*mu Rrf_mono + -0.0035*mu Tsf_mono + 3.68117969821674*(mu + 0.3915)/mu adp_c + 819.0 + 3.60641975308642*(mu + 0.3915)/mu amp_c + -819.0 - 3.68117969821674*(mu + 0.3915)/mu atp_c + 4.13871056241427*(mu + 0.3915)/mu cmp_c + for_c + 1640.0 gdp_c + -0.0035*mu generic_Tuf + 3.67818930041152*(mu + 0.3915)/mu gmp_c + -1641.0 - 3.68117969821674*(mu + 0.3915)/mu h2o_c + 2459.0 + 3.68117969821674*(mu + 0.3915)/mu h_c + -4.71780186438886*(mu + 0.3915)/mu mRNA_biomass + 1640.0 + 3.68117969821674*(mu + 0.3915)/mu pi_c + 819.0 ppi_c + protein_b0002 + 89.10310623999999 protein_biomass + -0.0117560296704137*mu - 0.00460248561596696 ribosome + thf_c + 3.30737997256516*(mu + 0.3915)/mu ump_c'

# %%
ecome.reactions.transcription_TU_8385_from_RPOE_MONOMER.reaction
# Out:
# '741.0 atp_c + 894 ctp_c + 722 gtp_c + 3.0 h2o_c + 738 utp_c --> -4.27350427350427e-6*mu GreA_mono + -4.27350427350427e-6*mu GreB_mono + -4.27350427350427e-6*mu Mfd_mono_mod_1:mg2 + -4.27350427350427e-6*mu NusA_mono + -4.27350427350427e-6*mu NusG_mono + -0.0147762779434631*mu - 0.00578491281486579 RNAPE-CPLX + RNA_b2512 + -4.27350427350427e-6*mu Rho_hexa_mod_3:mg2 + -4.27350427350427e-6*mu RpoZ_mono_mod_1:mg2 + 3.0 adp_c + 3.0 h_c + 377.24044735900003 mRNA_biomass + 3.0 pi_c + 3092 ppi_c'

# %%
for k,v in ecome.reactions.translation_b0002.metabolites.items():
    if not isinstance(v,float) and not isinstance(v,int):
        print(k.id, v)
# Out:
# h2o_c -1641.0 - 3.68117969821674*(mu + 0.3915)/mu
# ribosome -0.0117560296704137*mu - 0.00460248561596696
# RNA_b0002 -0.000498399634202103*mu - 0.000195123456790123 - 0.00598079561042524*(mu + 0.3915)/mu
# ump_c 3.30737997256516*(mu + 0.3915)/mu
# amp_c 819.0 + 3.60641975308642*(mu + 0.3915)/mu
# cmp_c 4.13871056241427*(mu + 0.3915)/mu
# gmp_c 3.67818930041152*(mu + 0.3915)/mu
# atp_c -819.0 - 3.68117969821674*(mu + 0.3915)/mu
# adp_c 3.68117969821674*(mu + 0.3915)/mu
# pi_c 1640.0 + 3.68117969821674*(mu + 0.3915)/mu
# h_c 2459.0 + 3.68117969821674*(mu + 0.3915)/mu
# RNA_degradosome -2.55589556001079e-8*mu - 1.00063311174422e-8
# generic_Tuf -0.0035*mu
# PrfB_mono -1.63370183870619e-7*mu
# InfA_mono -4.27350427350427e-6*mu
# InfB_mono -4.45382843794892e-6*mu
# Fmt_mono_mod_mg2_mod_k -1.80324164444648e-7*mu
# InfC_mono -4.27350427350427e-6*mu
# FusA_mono -0.0035*mu
# Tsf_mono -0.0035*mu
# PrfC_mono -4.27350427350427e-6*mu
# Def_mono_mod_1:fe2 -2.72438972852433e-7*mu
# Rrf_mono -2.62130898398882e-7*mu
# mRNA_biomass -4.71780186438886*(mu + 0.3915)/mu
